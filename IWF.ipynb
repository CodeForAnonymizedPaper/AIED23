# %%
import spacy
import pandas as pd
from transformers import pipeline, AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
from sentence_transformers import SentenceTransformer, util
from lexicalrichness import LexicalRichness
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import re
import math
import random

#synonym testing
import numpy as np
nlp = spacy.load('en_core_web_lg')
import nltk
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from nltk.tokenize import word_tokenize, sent_tokenize
import openai
openai.api_key = 'REPLACE_WITH_YOUR_KEY'
model_engine = "text-davinci-003"

# %%
nl = '\n'
class MultipleChoiceQuestion:
    def __init__(self, stem, options, correct_option, qid = None, courseid = None, quality = None):
        self.stem = stem
        self.options = options
        self.correct_option = correct_option
        self.qid = qid
        self.courseid = courseid
        self.quality = quality
        
    def __str__(self):
        return f"Question: {self.stem}\n {nl.join(self.options)}\nCorrect option: {self.correct_option}\nQuality: {self.quality}"

# %%
#https://huggingface.co/cointegrated/roberta-large-cola-krishna2020
#Ranking Distractors for Multiple Choice Questions Using Multichannel Semantically Informed CNN-LSTM Networks
cola = pipeline('text-classification', model='cointegrated/roberta-large-cola-krishna2020',truncation=True)

def ambiguous_unclear_information(question):
    output = cola(question.stem)
    score = output[0]['score']
    if score >= 0.7:
        return True
    else:
        print('--- Question stem is unclear')
        return False

# %%
#semantic specificity and semantic homogeneity 
#semantic relatedness of answer and other options
#model_gigaword = api.load("glove-wiki-gigaword-100")
#model_gigaword.most_similar(positive=['dirty','grimy'],topn=10)
#v_apple = model_gigaword['Paris']
#v_mango = model_gigaword['London']
#cosine_similarity([v_apple],[v_mango])

#https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2
#Distractor Quality Evaluation in Multiple Choice Questions
#Ranking Distractors for Multiple Choice Questions Using Multichannel Semantically Informed CNN-LSTM Networks
model = SentenceTransformer('all-MiniLM-L6-v2')


#Uses NER, so if the score is too low, if they're matching entities (i.e. people) then we can ignore this case and say True
#For example, these two are similar, they're just both entities not recognized. 
#--- distractor not similar enough
#Millikan 		 Rutherford 		 Score: 0.1707
def implausible_distractors(question):
    correct = question.correct_option
    options = question.options.copy()
    options.remove(correct)

    # Two lists of sentences
    sentences1 = [correct, correct, correct]
    sentences2 = options

    #Compute embedding for both lists
    embeddings1 = model.encode(sentences1, convert_to_tensor=True)
    embeddings2 = model.encode(sentences2, convert_to_tensor=True)

    #Compute cosine-similarities
    cosine_scores = util.cos_sim(embeddings1, embeddings2)

    #Output the pairs with their score
    for i in range(len(sentences1)):
        if cosine_scores[i][i] < 0.15: #Was .2
            
            #NER check here...
            opt_entity = nlp(sentences2[i])
            lemma_nouns_opt = get_lemma_nouns(sentences2[i])
            print('opt_entity: ', opt_entity)
            print('lemma_nouns_opt: ', lemma_nouns_opt)
            
            ans_entity = nlp(sentences1[i])
            lemma_nouns_ans = get_lemma_nouns(sentences1[i])
            print('ans_entity: ', ans_entity)
            print('lemma_nouns_ans: ', lemma_nouns_ans)
            

            #If the noun(s) in the answer choice can be tagged with an entity
            if ans_entity.ents:
                answer_entity = ans_entity.ents[0].label_
            else:
                answer_entity = None

            if opt_entity.ents:
                opt_entity = opt_entity.ents[0].label_
            else:
                opt_entity = None

            if answer_entity and opt_entity and answer_entity in opt_entity:
                print('*** low score, but they are the same entity', answer_entity, ' & ', opt_entity)
                return True
            
            if len(lemma_nouns_ans) == 0 and len(lemma_nouns_opt) == 0:
                #Couldn't find the noun nor the entity? Unable to parse effectively to make a judgement.
                print('*** no noun or entity, cant judge')
                return True
            
            #If the option in this case is none/all of the above, it won't be similar, so ignore this criteria
            if not all_of_the_above(question) or not none_of_the_above(question):
                return True
            
            print('--- distractor not similar enough')
            print("{} \t\t {} \t\t Score: {:.4f}".format(sentences1[i], sentences2[i], cosine_scores[i][i]))
            return False
        
    return True

# %%
def none_of_the_above(question):
    print(question)
    for opt in question.options:

        cleaned_opt = opt.strip().lower()
        if 'none of the above' in cleaned_opt or ('none' in cleaned_opt and 'above' in cleaned_opt) or cleaned_opt == 'neither' or cleaned_opt == "none" or 'none' in question.options[3]:
            print('--- none of the above')
            return False
    
    return True

# %%
#If the correct answer is noticably longer (20% or more) than the second longest answer, flag it.
def longest_answer_correct(question):
    correct = question.correct_option
    options = question.options.copy()
    options.remove(correct)
    
    longest_option = 0
    for opt in options:
        if len(opt) >= longest_option:
            longest_option = len(opt)
        
    #If the longest option is only by 20% or it's a single word/number, then this passes
    if longest_option >= len(correct) * 0.8 or len(correct.split()) == 1:
        return True
    
    print('--- longest option is correct')
    return False

# %%
def gratuitous_information_in_stem(question):  
    #How effective are lexical richness measures for differentiations of vocabulary proficiency? A comprehensive examination with clustering analysis
    #https://github.com/LSYS/LexicalRichness
    #If the lexical richness is too wild...it's gratutious 
    stem = LexicalRichness(question.stem)
    
    if stem.cttr > 4.5:
        print("--- CTTR above 4.5, text is too complex and extraneous: ", stem.cttr)
        return False
    
    return True

# %%
s = "This is a test. Here is some extraneous information. Which of these is not true?"
for sent in s.split('.'):
    sent = sent.lower()
    print('sent: ' , sent)
    if 'which' in sent and 'not' in sent:
        print('negative word')
# Out:
# sent:  this is a test
# sent:   here is some extraneous information
# sent:   which of these is not true?
# negative word

# %%
#Question should not be a series of true/false statements, so we can look for "which" and "true" or "false" in the stem
def true_or_false(question):
    correct = question.correct_option
    options = question.options.copy()
    options.remove(correct)
    
    #Check for neatively worded stem too.
    for sent in question.stem.split('.'):
        sent = sent.lower()
        if 'which' in sent and ('false' in sent or 'true' in sent):
            return False    
    
    for opt in options:
        if opt.strip().lower() == 'true' or opt.strip().lower() == 'false' or opt.strip().lower() == 'yes'or opt.strip().lower() == 'no':
            print('--- There is a true/false or yes/no answer choice')
            return False

    return True

# %%
def avoid_convergence_cues(question):
    #Check for synonyms, because they'll know it's the word they've most recently come across in the text
    #The correct option is likely to be used more (when in pairs, etc.) --> k-type (super similar by description)
    #https://www.rcpch.ac.uk/sites/default/files/rcpch/HTWQ/convergence.html
    
    #So here we check for synonyms used in the words, in case they get lazy with distractors
    options = question.options.copy()
    options.remove(question.correct_option)
    if len(options) < 3:
        return True
    
    lemma_nouns_answ = get_lemma_nouns(question.correct_option)
    lemma_nouns_options = [get_lemma_nouns(options[0]), get_lemma_nouns(options[1]), get_lemma_nouns(options[2])]
    
    #so we want this code, but like, for synonyms
    synonyms = []
    for noun in lemma_nouns_answ:
        for syn in wn.synsets(noun):
            for l in syn.lemmas():
                synonyms.append(l.name().lower().replace('_', ' '))
    
    for opt in lemma_nouns_options:
        repeating_nouns_synonyms = list(set(synonyms).intersection(opt))
        print("repeating_nouns_synonyms: ", repeating_nouns_synonyms)
        if len(repeating_nouns_synonyms) > 0:           
            
            #if the repeat is not in every answer choice, flag it.
            for rns in repeating_nouns_synonyms:           
                
                flag = True
                for value in lemma_nouns_options:
                    if rns not in value:
                        print('--- we have a synonym of the answer being used in other answer choices, but not all of them: ', rns)
                        return False
    
    return True

# %%
#An example of a logical cue is asking students to select the most appropriate pharmaceutical intervention for a problem and
#only having one or two options which

def avoid_logical_cues(question):
    #NER? If the question asks for a <certain type of noun, like a person> then the options should all be <people> too.
    #so do NER on the answer and see if we get those in the other options
    
    options = question.options.copy()
    options.remove(question.correct_option)
    if len(options) < 3:
        return True
    
    lemma_nouns_answ = get_lemma_nouns(question.correct_option)
    lemma_nouns_options = [get_lemma_nouns(options[0]), get_lemma_nouns(options[1]), get_lemma_nouns(options[2])]
    
    entities_in_options = []
    for opt in lemma_nouns_options:
        for val in opt:
            doc = nlp(val)
            if doc.ents:
                entities_in_options.append(doc.ents[0].label_)
    
    entities_in_answer = []
  
    for val in lemma_nouns_answ:
        doc = nlp(val)
        
        #If the noun(s) in the answer choice can be tagged with an entity
        if doc.ents:
            answer_entity = doc.ents[0].label_
            if answer_entity not in entities_in_options:
                print('--- The answer entity is not found in any other options: ', answer_entity)
                return False 
    
    return True

# %%
def all_of_the_above(question):
    for opt in question.options:
        if 'all of the above' in opt or ('all' in opt and 'above' in opt) or ('all if the' in opt):
            print('--- all of the above')
            return False

    return True

# %%
#Might change to be more than a single underscore? For example, __
def fill_in_the_blank(question):
    if "_" in question.stem:
        print('--- fill in the blank')
        return False
    
    return True

# %%
#This one might need POS tagging too, because an absolute term isn't a deal breaker in some cases
# i.e. "Why does Hydrogen never bond with...?" 
def absolute_terms(question):
    absolutes = ["always", "never", "every", "none", "only"]
    for opt in question.options:
        #Count all, but not in the case of "all of the above"
        if any(word in opt for word in absolutes) or ("all" in opt and all_of_the_above(question)):
            print('--- absolute word in question stem')
            return False
    
    return True

# %%
#Find the nouns in question.correct_option and question.stem --> stem them --> compare cosine similiary (usin sentence transformer)
#Also check for the synonyms, compare them. However, if the word(s) are used in the other options, then it's fine.
#PoS tagging -> lemma -> Synonyms -> Cosine similarity 
#Technically I could check synonyms between stem and other answer choices, but I wont.

lemmatizer = WordNetLemmatizer()
#Nouns: NN noun, singular ‘- desk’, NNS noun plural – ‘desks’, NNP proper noun, singular – ‘Harrison’, NNPS proper noun, plural – ‘Americans’ 
nouns = ['NN', 'NNS', 'NNP', 'NNPS']

def word_repeats_in_stem_and_correct_answer(question):   
    lemma_nouns_stem = get_lemma_nouns(question.stem)        
    lemma_nouns_answ = get_lemma_nouns(question.correct_option)
    
    repeating_nouns = list(set(lemma_nouns_stem).intersection(lemma_nouns_answ))
    
    #check for synonms in question stem w/ answer choice
    synonyms = []
    for noun in lemma_nouns_stem:
        for syn in wn.synsets(noun):
            for l in syn.lemmas():
                synonyms.append(l.name().lower().replace('_', ' '))
                
    repeating_nouns_synonyms = list(set(synonyms).intersection(lemma_nouns_answ))
    
    #If we get a repeat, then it should also repeat in the other answer choices, not just the correct!
    if len(repeating_nouns) > 0 or len(repeating_nouns_synonyms) > 0:
        options = question.options.copy()
        options.remove(question.correct_option)
        options_that_share_noun = 0
        
        for opt in options:
            lemma_option = get_lemma_nouns(opt)
            repeating_nouns_ans_opt = list(set(lemma_option).intersection(lemma_nouns_answ))
            if len(repeating_nouns_ans_opt) > 0:
                options_that_share_noun += 1
        
        #If the word is shared between all options, then it is fine
        if options_that_share_noun == 3 or all_of_the_above(question) or none_of_the_above(question):
            return True
        else:
            print('--- The noun is only shared in certain words')
            return False
        
    #Check for word (adjective, noun, verb, adverb) that repeats just in stem and answer    
    word_types = ['NN', 'NNS', 'NNP', 'NNPS', 'RB', 'RBR', 'RBS', 'VB', 'VBG', 'VBN', 'VBP', 'VBZ']
    stem_token = sent_tokenize(question.stem)
    stem_words = []
    for i in stem_token:
        wordsList = nltk.word_tokenize(i)
        wordsList = [w for w in wordsList if not w in stop_words]
        tagged = nltk.pos_tag(wordsList)
        for t in tagged:
            if t[1] in word_types:
                stem_words.append(t[0].lower())
                
    ans_token = sent_tokenize(question.correct_option)
    ans_words = []
    for i in ans_token:
        wordsList = nltk.word_tokenize(i)
        wordsList = [w for w in wordsList if not w in stop_words]
        tagged = nltk.pos_tag(wordsList)
        for t in tagged:
            if t[1] in word_types:
                ans_words.append(t[0].lower())
    
    if any(x in stem_words for x in ans_words):
        return False

    
    return True

def get_lemma_nouns(text):
    all_nouns = []
    tokenized = sent_tokenize(text)
    
    for i in tokenized:

        # Word tokenizers is used to find the words and punctuation in a string
        wordsList = nltk.word_tokenize(i)

        # removing stop words from wordList
        wordsList = [w for w in wordsList if not w in stop_words]

        #  Using a Tagger. Which is part-of-speech tagger or POS-tagger.
        tagged = nltk.pos_tag(wordsList)
        
        # Add any nouns to this list
        for t in tagged:
            if t[1] in nouns:
                all_nouns.append(t[0].lower())
    
    lemmatized_nouns = []
    for n in all_nouns:
        lemmatized_word = lemmatizer.lemmatize(n, pos="n")
        lemmatized_nouns.append(lemmatized_word.lower())
    
    return lemmatized_nouns

# %%
#Readability score (perhaps BLEU and shit, maybe the BERT-based one?)
def unfocused_stem(question):
    contains_question = False
    doc = nlp(question.stem)
    for sent in doc.sents:
        if is_question(sent.text.strip()):
            contains_question = True
            
    if not contains_question:
        print("--- Question stem does not contain a question")
        
    return contains_question

#https://stackoverflow.com/questions/72548388/is-there-a-machine-learning-or-nlp-model-to-separate-questions-and-answers-in-ra
#https://stackoverflow.com/questions/4083060/determine-if-a-sentence-is-an-inquiry
def is_question(sent):
    d = nlp(sent)
    token = d[0] # gets the first token in a sentence
    if token.pos_ == "VERB" and token.dep_ == "ROOT": # checks if the first token is a verb and root or not
        return True
    for token in d: # loops through the sentence and checks for WH tokens
        if token.tag_ == "WDT" or token.tag_ == "WP" or token.tag_ == "WP$" or token.tag_ == "WRB" or token.text == '?':
            return True
    return  False

# %%
def clean_string(string):
    # remove whitespace
    cleaned_string = string.strip()
    
    # remove punctuation
    cleaned_string = re.sub(r'[^\w\s]', '', cleaned_string)
    
    # remove list notation
    cleaned_string = re.sub(r'\b(i|ii|iii|iv|v|vi|vii|viii|ix|x|xi|xii|xiii|xiv|xv|xvi|xvii|xviii|xix|xx)\b', '', cleaned_string)
    cleaned_string = re.sub(r'\b(A|B|C|D|E|F)\b', '', cleaned_string)
    print('cleaned_string: ', cleaned_string)
    return cleaned_string

#Check for commas in the answer choices? Repeated words between answer choices?
#Also similar to the convergence cue one
#Now it does a good job picking up on teh 1. or ii/iii/iv or (A) (B) (C) style questions, how can we do that?
def complex_k_type(question):
    #if the answer options share the same words between one another 
    #and there are commas present
    #then it's k type
    #also the stem says "Select all that apply" or "Select all" in general?
    
    options = question.options.copy()
    options.remove(question.correct_option)
    if len(options) < 3:
        return True 
    
    #check if the options contain a comma
    contain_a_comma = 0
    for opt in options:
        if ',' in opt:
            contain_a_comma += 1
    contain_a_comma = contain_a_comma == len(options)
    
    lemma_nouns_answ = get_lemma_nouns(question.correct_option)
    lemma_nouns_options = [get_lemma_nouns(options[0]), get_lemma_nouns(options[1]), get_lemma_nouns(options[2])]
    
    options_that_share_noun = 0
    for lno in lemma_nouns_options:   
        repeating_nouns = list(set(lno).intersection(lemma_nouns_answ))
        if (len(repeating_nouns) > 0) and (len(lno) > 0):
            options_that_share_noun += 1
    
    #Options share a key word, there are multiple nouns in the options, and they have a comma
    #suggesting it might be a k-type question
    if options_that_share_noun > 0 and contain_a_comma:
        print("--- This might be a K-type question")
        return False
    
    #After removing any list notation in the answer choices, see if they contain the same words
    cleaned_options = []
    for opt in options:
        cleaned_options.append(clean_string(opt))

    options_set_list = [set(i.split()) for i in cleaned_options]
    if options_set_list[0] == options_set_list[0] and options_set_list[0] == options_set_list[1] and options_set_list[0] == options_set_list[2]:
        return False
    
    return True

# %%
#If verb exists in answer choice, ensure it's the same tense as verb in other options
# we want the stem to be the same, but as long as all the answers are the same, then it's fine, to avoid false positive

# (Done in logical cue) NER, if the answer choice contains a specific type of noun, the other options should likely contain that
#VB  --  verb, base form
# VBD  --  verb, past tense
# VBG  --  verb, gerund or present participle
# VBN  --  verb, past participle
# VBP  --  verb, non-3rd person singular present
# VBZ  --  verb, 3rd person singular present

def grammatical_cues_in_stem(question):
    stem_tense = get_verb_tense(question.stem)
    answer_tense = get_verb_tense(question.correct_option)
    
    options = question.options.copy()
    options.remove(question.correct_option)
    for opt in options:
        opt_tense = get_verb_tense(opt)
        if opt_tense != 'none' and answer_tense is not opt_tense:
            print("--- verb tense doesn't align between answer other options")
            return False
        
    return True
    
def get_verb_tense(text):
    doc = nlp(text)
    for token in doc:
        if token.pos_ == 'VERB':
            if token.tag_ in ['VBP', 'VBZ']:
                return 'present'
            elif token.tag_ in ['VBD', 'VBN']:
                return 'past'
            else:
                return 'other'
    return 'none'

# %%
#If answer choices are numeric, sort them, compare to current order
#Otherwise how the hell do we know this one..? No need to alphabetize imo (unless it’s like one word)
def lost_sequence(question):
    options = question.options.copy()
    
    opts = []
    for opt in options:
        opt = re.sub(r'[$%°FC,]', '', opt)
        opts.append(opt)
        try:
            float(opt)
        except ValueError:
            return True
        
    float_options = [float(x) for x in opts]    
    sorted_options = sorted(float_options)
    if sorted_options == float_options:
        #Numeric options are sorted
        return True
    else:
        print('--- Options are numeric and not sorted')
        return False

# %%
#This one might need POS tagging too, because an absolute term isn't a deal breaker in some cases
# i.e. "Why does Hydrogen never bond with...?" 
def vague_terms(question):
    vagues = ["often", "sometimes", "rarely", "typically", "usually", "normally", "generally", "nearly", "approximately", "more or less", "somewhat"]
    for opt in question.options:
        if any(word in opt for word in vagues):
            print('--- vague word in question stem')
            return False
    
    return True

# %%
#QA model confirm correct answer is correct → (make the QA model do it’s best guess, 
#but maybe use like gpt-3 AND some QA model?)
#I think we can say “all answers are correct, the QA Model was great, but in the future something more robust 
#like ChatGPT should be utilized? As we input all the questions and they were right.
completion = None
def more_than_one_correct(question):
    if not question.options[2]:
        question.options[2] = 'None'
        
    if not question.options[3]:
        question.options[3] = 'None'
    
    # Define the prompt
    prompt = """
    Answer the multiple-choice question below by responding with A, B, C, or D.
    
    {}

    A) {}
    B) {}
    C) {}
    D) {}
    """.format(question.stem, question.options[0], question.options[1], question.options[2], question.options[3])

    # Generate a response
    completion = openai.Completion.create(engine=model_engine, prompt=prompt, max_tokens=1024, n=1,stop=None,temperature=0.5)

    # Print the response
    try:
        #cleaned_response = completion.choices[0].text.split(')')[1].strip()
        cleaned_response = completion.choices[0].text.split(')')[0].strip()
        if (cleaned_response == 'A'):
            cleaned_response = question.options[0]
        elif (cleaned_response == 'B'):
            cleaned_response = question.options[1]
        elif (cleaned_response == 'C'):
            cleaned_response = question.options[2]
        elif (cleaned_response == 'D'):
            cleaned_response = question.options[3]
    except: 
        print('error in GPT3: ', completion)
    
    if cleaned_response == question.correct_option:
        return True
    else:
        print('--- GPT-3 believes the answer is incorrect: ', cleaned_response, ' ', question.correct_option)
        return False

# %%
#This one might need POS tagging too, because an negative term isn't a deal breaker in some cases
# i.e. "If there is no oxygen present when the chemical reacts, then what does...?" 
#Sentiment analysis for this? nlp determine if something is negatively worded
#Now it checks for "not" and "incorrect" and "false" paired with "Which" in the same sentence? Perhaps split by period
def negative_worded_stem(question):
    negatives = ["no", "none", "never", "without", "exclude", "avoid", "deny", "refuse", "oppose", "dispute"]
    for opt in question.stem:
        if any(word in opt for word in negatives):
            print('--- absolute word in question stem')
            return False
    
    #Check for neatively worded stem too.
    for sent in question.stem.split('.'):
        sent = sent.lower()
        #What is common too, but might have too many falses?
        if 'which' in sent and ('false' in sent or 'not' in sent or 'incorrect' in sent or 'except' in sent) or \
        'what' in sent and ('false' in sent or 'not' in sent or 'incorrect' in sent or 'except' in sent):
            return False    
    
    
    return True

# %% [markdown]
# ## Peerwise Biochemistry Data - 400 Questions

# %%
qs = pd.read_csv('peerwise_questions.csv')
# filtered_df = qs.loc[(qs['avg_rating'] > 3.49) & (qs['total_ratings'] > 9) & (qs['numAlts'] == 4)]
# filtered_df = filtered_df[~filtered_df['question'].str.casefold().str.contains("img")]
columns_to_clean = ['question', 'altA', 'altB', 'altC', 'altD']

def clean_peerwise_data(cdf):
    for cName in columns_to_clean:
        cdf[cName] = cdf[cName].str.replace(r'<[^<>]*>', ' ', regex=True)
        cdf[cName] = cdf[cName].apply(lambda x: re.sub("&nbsp;",  "", x))
        cdf[cName] = cdf[cName].str.replace(' +', ' ', regex=True)
        cdf[cName] = cdf[cName].str.strip()

    peerwise_student_questions = []
    for index, row in cdf.iterrows():
        question = MultipleChoiceQuestion(
            stem=row['question'],
            options=[row['altA'], row['altB'], row['altC'], row['altD']],
            correct_option= row['alt' + row['answer'].strip()],
            qid = row['total_response'],
            courseid = row['avg_difficulty'],
            quality = row['avg_rating']
        )
        if not question.stem or not question.options[0] or not question.options[1] or not question.options[2] or not question.options[3]:
            print('removing empty option question')
        else:
            peerwise_student_questions.append(question)
    
    selected_items = random.sample(peerwise_student_questions, 400)
    return selected_items


# # biochem_lowest_df = qs.loc[(qs['avg_rating'] < 2.0) & (qs['avg_rating'] > 1.49) & (qs['total_ratings'] > 9) & (qs['numAlts'] == 4)]
# # biochem_lowest = clean_peerwise_data(biochem_lowest_df)

# # biochem_low_df = qs.loc[(qs['avg_rating'] < 2.5) & (qs['avg_rating'] > 1.99) & (qs['total_ratings'] > 19) & (qs['numAlts'] == 4)]
# # biochem_low = clean_peerwise_data(biochem_low_df)

# # biochem_mid_df = qs.loc[(qs['avg_rating'] < 3.0) & (qs['avg_rating'] > 2.49) & (qs['total_ratings'] > 19) & (qs['numAlts'] == 4)]
# # biochem_mid = clean_peerwise_data(biochem_mid_df)

# # biochem_high_df = qs.loc[(qs['avg_rating'] < 3.5) & (qs['avg_rating'] > 2.99) & (qs['total_ratings'] > 19) & (qs['numAlts'] == 4)]
# # biochem_high = clean_peerwise_data(biochem_high_df)

# # biochem_highest_df = qs.loc[(qs['avg_rating'] > 3.49) & (qs['total_ratings'] > 6) & (qs['numAlts'] == 4)]
# # biochem_highest = clean_peerwise_data(biochem_highest_df)

# # peerwise_student_questions = biochem_lowest + biochem_low + biochem_mid + biochem_high + biochem_highest    
# # print('length: ', len(peerwise_student_questions))

take2 = qs.loc[(qs['total_response'] > 29) & (qs['numAlts'] == 4)]
biochem_take2 = clean_peerwise_data(take2)

peerwise_student_questions = biochem_take2

rows = []
i = 0
for q in peerwise_student_questions:
    r = [ambiguous_unclear_information(q),
        implausible_distractors(q),
        none_of_the_above(q),
        longest_answer_correct(q),
        gratuitous_information_in_stem(q),
        true_or_false(q),
        avoid_convergence_cues(q),
        avoid_logical_cues(q),
        all_of_the_above(q),
        fill_in_the_blank(q),
        absolute_terms(q),
        word_repeats_in_stem_and_correct_answer(q),
        unfocused_stem(q),
        complex_k_type(q),
        grammatical_cues_in_stem(q),
        lost_sequence(q),
        vague_terms(q),
        #more_than_one_correct(q),
        negative_worded_stem(q),
        q.qid,
        q.courseid,
        q.quality]
    rows.append(r)
    print('i: ', i)
    i += 1
    
columns = [
    'ambiguous_unclear_information',
    'implausible_distractors',
    'none_of_the_above',
    'longest_answer_correct',
    'gratuitous_information_in_stem',
    'true_or_false',
    'avoid_convergence_cues',
    'avoid_logical_cues',
    'all_of_the_above',
    'fill_in_the_blank',
    'absolute_terms',
    'word_repeats_in_stem_and_correct_answer',
    'unfocused_stem',
    'complex_k_type',
    'grammatical_cues_in_stem',
    'lost_sequence',
    'vague_terms',
    #'more_than_one_correct',
    'negative_worded_stem',
    'qid',
    'courseid',
    'quality'
]

peerwise_results = pd.DataFrame(rows, columns=columns)
peerwise_results.to_csv("peerwise_400diffv2_results_auto_iwf.csv")

#Print the number of "Falses", which correspond to IWF, found the table across each criteria
peerwise_400diffv2_results = peerwise_results.copy()
peerwise_400diffv2_results = peerwise_400diffv2_results.drop(columns=['qid', 'courseid', 'quality'])
for c in columns[:len(columns)-3]:
    print(c, ': ', (~peerwise_400diffv2_results[c]).values.sum())
# Out:
# C:\Users\Steven\AppData\Local\Temp\ipykernel_15452\1702380357.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf[cName] = cdf[cName].str.replace(r'<[^<>]*>', ' ', regex=True)
# C:\Users\Steven\AppData\Local\Temp\ipykernel_15452\1702380357.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf[cName] = cdf[cName].apply(lambda x: re.sub("&nbsp;",  "", x))
# C:\Users\Steven\AppData\Local\Temp\ipykernel_15452\1702380357.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf[cName] = cdf[cName].str.replace(' +', ' ', regex=True)
# C:\Users\Steven\AppData\Local\Temp\ipykernel_15452\1702380357.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf[cName] = cdf[cName].str.strip()
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# removing empty option question
# opt_entity:  ETC coupling
# lemma_nouns_opt:  ['etc', 'coupling']
# ans_entity:  ATP production in type I muscle fibres
# lemma_nouns_ans:  ['atp', 'production', 'type', 'fibre']
# Question: Drug X inhibits the activity of carnitine. Which of the following processes is DIRECTLY affected by drug X?
#  Glycolysis
# ATP production in type I muscle fibres
# ATP production in type II muscle fibres
# ETC coupling
# Correct option: ATP production in type I muscle fibres
# Quality: 3.16
# --- distractor not similar enough
# ATP production in type I muscle fibres 		 ETC coupling 		 Score: 0.0992
# Question: Drug X inhibits the activity of carnitine. Which of the following processes is DIRECTLY affected by drug X?
#  Glycolysis
# ATP production in type I muscle fibres
# ATP production in type II muscle fibres
# ETC coupling
# Correct option: ATP production in type I muscle fibres
# Quality: 3.16
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['atp', 'fibre', 'type', 'production']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  atp
# cleaned_string:  Glycolysis
# cleaned_string:  ATP production in type II muscle fibres
# cleaned_string:  ETC coupling
# --- verb tense doesn't align between answer other options
# i:  0
# opt_entity:  Through passive diffusion through the inner membrane of the mitochondria
# lemma_nouns_opt:  ['diffusion', 'inner', 'membrane', 'mitochondrion']
# ans_entity:  Due to the gradient difference of OH-
# lemma_nouns_ans:  ['gradient', 'difference', 'oh-']
# Question: The transfer of protons by the protein motor force occurs:
#  Through passive diffusion through the inner membrane of the mitochondria
# Due to the difference concentrations of Na+ and K+
# By transferring protons from low pH to high pH
# Due to the gradient difference of OH-
# Correct option: Due to the gradient difference of OH-
# Quality: 2.61
# --- distractor not similar enough
# Due to the gradient difference of OH- 		 Through passive diffusion through the inner membrane of the mitochondria 		 Score: 0.0804
# Question: The transfer of protons by the protein motor force occurs:
#  Through passive diffusion through the inner membrane of the mitochondria
# Due to the difference concentrations of Na+ and K+
# By transferring protons from low pH to high pH
# Due to the gradient difference of OH-
# Correct option: Due to the gradient difference of OH-
# Quality: 2.61
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['difference']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  difference
# --- Question stem does not contain a question
# cleaned_string:  Through passive diffusion through the inner membrane of the mitochondria
# cleaned_string:  Due to the difference concentrations of Na and K
# cleaned_string:  By transferring protons from low pH to high pH
# --- verb tense doesn't align between answer other options
# i:  1
# Question: C3-17: Muscle Gluts in Starvation Which of the following statements regarding glut transporters 1 and 4 in starvation is correct?
#  Due to a decrease in glucose concentration there will be a decrease in insulin produced, therefore glut 1 transporters will no longer be active on the tissue surface
# Due to a decrease in glucose, glut 1 transporters will no longer be able take up glucose and therefore can no longer partake in glycolysis
# Due to a decrease in glucose, there will be a decrease in insulin and insulin binding to its receptor which causes glut 4 transporter to be inactivated
# There is no change to glut 1 and 4 transporters in starvation
# Correct option: Due to a decrease in glucose, there will be a decrease in insulin and insulin binding to its receptor which causes glut 4 transporter to be inactivated
# Quality: 2.82
# repeating_nouns_synonyms:  ['decrease', 'transporter', 'insulin']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  decrease
# cleaned_string:  Due to a decrease in glucose concentration there will be a decrease in insulin produced therefore glut 1 transporters will no longer be active on the tissue surface
# cleaned_string:  Due to a decrease in glucose glut 1 transporters will no longer be able take up glucose and therefore can no longer partake in glycolysis
# cleaned_string:  There is no change to glut 1 and 4 transporters in starvation
# --- verb tense doesn't align between answer other options
# i:  2
# Question: C4-29 Malonyl-CoA is a molecule which plays a part in bothlipogenesis and in the regulation of fat oxidation. Which of the following statements is false ?
#  Malonyl-CoA is formed by thecarboxylation of Acetyl-CoA. The conversion is irreversible.
# Malonyl-CoA regulates the oxidation of fat by binding to the active sites of carnitine molecules, preventing fatty acids from being transported inside the mitochondrial membrane.
# During lipogenesis, Malonyl-CoA assists in the building of the fatty acid chain by providing two carbon atoms.
# During lipogenesis, Malonyl-CoA interacts withmalonyl coenzyme a-acyl carrier protein transacylase (MCAT) to separate the malonate from the CoA segment and attach it instead to the MCAT molecule.
# Correct option: Malonyl-CoA regulates the oxidation of fat by binding to the active sites of carnitine molecules, preventing fatty acids from being transported inside the mitochondrial membrane.
# Quality: 3.06
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['atom', 'acid']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  atom
# cleaned_string:  MalonylCoA is formed by thecarboxylation of AcetylCoA The conversion is irreversible
# cleaned_string:  During lipogenesis MalonylCoA assists in the building of the fatty acid chain by providing two carbon atoms
# cleaned_string:  During lipogenesis MalonylCoA interacts withmalonyl coenzyme aacyl carrier protein transacylase MCAT to separate the malonate from the CoA segment and attach it instead to the MCAT molecule
# --- verb tense doesn't align between answer other options
# i:  3
# opt_entity:  Dephosphorylation by phosphatases
# lemma_nouns_opt:  ['dephosphorylation', 'phosphatase']
# ans_entity:  Long-chain fatty acyl-CoA
# lemma_nouns_ans:  ['acyl-coa']
# Question: Acetyl CoA Carboxylase is stimulated by the following factors or processes EXCEPT:
#  Citrate
# Dephosphorylation by phosphatases
# Insulin
# Long-chain fatty acyl-CoA
# Correct option: Long-chain fatty acyl-CoA
# Quality: 2.84
# --- distractor not similar enough
# Long-chain fatty acyl-CoA 		 Dephosphorylation by phosphatases 		 Score: 0.0736
# Question: Acetyl CoA Carboxylase is stimulated by the following factors or processes EXCEPT:
#  Citrate
# Dephosphorylation by phosphatases
# Insulin
# Long-chain fatty acyl-CoA
# Correct option: Long-chain fatty acyl-CoA
# Quality: 2.84
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- Question stem does not contain a question
# cleaned_string:  Citrate
# cleaned_string:  Dephosphorylation by phosphatases
# cleaned_string:  Insulin
# i:  4
# Question: Why do we hydrogenate fatty acids?
#  to form randomly placed trans bonds that can be easily oxidised
# to solidify fatty acids making them easier to spread
# to make trans fats which decrease the LDL:HDL ratio
# to increase the structural integrity and fluidity of fatty acid membranes
# Correct option: to solidify fatty acids making them easier to spread
# Quality: 2.82
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  to form randomly placed trans bonds that can be easily oxidised
# cleaned_string:  to make trans fats which decrease the LDLHDL ratio
# cleaned_string:  to increase the structural integrity and fluidity of fatty acid membranes
# i:  5
# Question: C1-17 What are the main characteristics of a rate limiting step, or enzyme, of metabolism?
#  Slow, [S] &lt;&lt; Km and saturated with substrate
# Fast, catalyses a reversible reaction and is working at Vmax
# Slow, catalyses a irreversible reaction and is working at Vmax
# Slow, operating under low [S] and catalyses an irreversible reaction
# Correct option: Slow, catalyses a irreversible reaction and is working at Vmax
# Quality: 2.82
# repeating_nouns_synonyms:  ['slow']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  slow
# --- This might be a K-type question
# --- verb tense doesn't align between answer other options
# i:  6
# Question: In our daily nitrogen balance:
#  The amount of output of nitrogen is less than the input
# Approximately 16.5g of nitrogen is excreted through urea everyday
# Approximately 16.5g of nitrogen is excreted through urea and faeces everyday
# The amount of input of nitrogen is the same as the output
# Correct option: The amount of input of nitrogen is the same as the output
# Quality: 2.5
# repeating_nouns_synonyms:  ['output', 'amount']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  output
# --- absolute word in question stem
# --- Question stem does not contain a question
# cleaned_string:  The amount of output of nitrogen is less than the input
# cleaned_string:  Approximately 165g of nitrogen is excreted through urea everyday
# cleaned_string:  Approximately 165g of nitrogen is excreted through urea and faeces everyday
# --- verb tense doesn't align between answer other options
# i:  7
# Question: The image above represents the flow of a chylomicron and its constituents around the body from production to degradation. What is missing in the boxes labelled A-D?
#  A: Small Intestine B: Lymphatic System C: Bloodstream D: Liver
# A: Large Intestine B: Lymphatic system C: Bloodstream D: Liver
# A: Liver B: Lymphatic System C: Small intestine D: Bloodstream
# A: Stomach B: Lymphatic system C: Bloodstream D: Liver
# Correct option: A: Small Intestine B: Lymphatic System C: Bloodstream D: Liver
# Quality: 2.93
# repeating_nouns_synonyms:  ['liver', 'intestine', 'd', 'system', 'c', 'bloodstream', 'b']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  intestine
# --- absolute word in question stem
# cleaned_string:   Large Intestine  Lymphatic system  Bloodstream  Liver
# cleaned_string:   Liver  Lymphatic System  Small intestine  Bloodstream
# cleaned_string:   Stomach  Lymphatic system  Bloodstream  Liver
# --- verb tense doesn't align between answer other options
# i:  8
# Question: Sally is a BCHM2072 student who works part time on weekends at a gym. She over hears some customers talking about an exciting new type of sports drink they read about in "mens health" magazine. One of the customers claims it works so well because of the new type of carbohydrate they are using in it. What facts about this new compound are most likely to be correct?
#  It is a disaccharide made up of glucose and fructose molecules. The glucose rings cannot open and close due to a glycosidic bond at the alpha carbon. This leaves other options available for bond formation such as carbon 6. In theory the carbohydrate will be absorbed twice as fast because its only half glucose.
# It is a branched molecule made up of glucose molecules. These glucose rings can open and close freely. This makes it easier for the molecule to pass through cell walls. In theory the glucose will be absorbed at the same rate it is used up.
# It is a branched molecule made up of glucose molecules. These glucose rings cannot open and close due to a glycosidic bond at the alpha carbon. This leaves other options available for bond formation such as carbon 6. In theory the glucose will be absorbed at the same rate it is used up.
# It is a branched molecule made up of glucose molecules. These glucose rings cannot open and close due to a glycosidic bond at the alpha carbon. This leaves other options available for bond formation such as carbon 4. In theory the glucose will be absorbed at the same rate it is used up.
# Correct option: It is a branched molecule made up of glucose molecules. These glucose rings cannot open and close due to a glycosidic bond at the alpha carbon. This leaves other options available for bond formation such as carbon 6. In theory the glucose will be absorbed at the same rate it is used up.
# Quality: 2.45
# repeating_nouns_synonyms:  ['ring', 'carbon', 'theory', 'molecule', 'alpha', 'option', 'formation', 'bond']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  carbon
# --- absolute word in question stem
# cleaned_string:  It is a disaccharide made up of glucose and fructose molecules The glucose rings cannot open and close due to a glycosidic bond at the alpha carbon This leaves other options available for bond formation such as carbon 6 In theory the carbohydrate will be absorbed twice as fast because its only half glucose
# cleaned_string:  It is a branched molecule made up of glucose molecules These glucose rings can open and close freely This makes it easier for the molecule to pass through cell walls In theory the glucose will be absorbed at the same rate it is used up
# cleaned_string:  It is a branched molecule made up of glucose molecules These glucose rings cannot open and close due to a glycosidic bond at the alpha carbon This leaves other options available for bond formation such as carbon 4 In theory the glucose will be absorbed at the same rate it is used up
# i:  9
# Question: When bacterial DNA is replicated in the lab, the first step of PCR is to heat DNA to 95 deg C. However, when bacterial cells do this of their own accord, they remain at a temperature close to 37 deg C. What solution do cells provide instead of increasing their temperature, and what challenge does this overcome?
#  Single stranded binding proteins; unwind ds DNA
# Topoisomerase; seals ds DNA
# Helicase; unwinds ds DNA
# Primase; seals ds DNA
# Correct option: Helicase; unwinds ds DNA
# Quality: 2.9
# repeating_nouns_synonyms:  ['dna']
# repeating_nouns_synonyms:  ['dna']
# repeating_nouns_synonyms:  ['dna']
# cleaned_string:  Single stranded binding proteins unwind ds DNA
# cleaned_string:  Topoisomerase seals ds DNA
# cleaned_string:  Primase seals ds DNA
# --- verb tense doesn't align between answer other options
# i:  10
# Question: Which of the following description regarding the inner andouter mitochondrial membrane is not true ?
#  The outer membrane has many protein-based pores that are big enough to allow the passage of ions and molecules as large as a small protein.
# ATP synthesized in mitochondria must be transported out from the outer mitochondrial membrane to be available for cellular functions.
# Fatty acids are unable to pass through the inner mitochondrial membrane without the carrier carnitine.
# protons are pumped across the outer mitochondrial membrane as electrons flow through the respiratory chain.
# Correct option: protons are pumped across the outer mitochondrial membrane as electrons flow through the respiratory chain.
# Quality: 2.96
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['membrane']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  membrane
# --- absolute word in question stem
# cleaned_string:  The outer membrane has many proteinbased pores that are big enough to allow the passage of ions and molecules as large as a small protein
# cleaned_string:  ATP synthesized in mitochondria must be transported out from the outer mitochondrial membrane to be available for cellular functions
# cleaned_string:  Fatty acids are unable to pass through the inner mitochondrial membrane without the carrier carnitine
# --- verb tense doesn't align between answer other options
# i:  11
# Question: Dinitrophenol causes: A. Inhibition of ATP synthase B. Inhibition of electron transport C. Uncoupling of oxidation and phosphorylation D. Accumulation of ATP
#  Inhibition of ATP synthase
# Inhibition of electron transport
# Uncoupling of oxidation and phosphorylation
# Accumulation of ATP
# Correct option: Uncoupling of oxidation and phosphorylation
# Quality: 1.94
# --- longest option is correct
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- Question stem does not contain a question
# cleaned_string:  Inhibition of ATP synthase
# cleaned_string:  Inhibition of electron transport
# cleaned_string:  Accumulation of ATP
# i:  12
# opt_entity:  DNA Polymerase 1
# lemma_nouns_opt:  ['dna', 'polymerase']
# ans_entity:  dNTPs
# lemma_nouns_ans:  ['dntps']
# Question: Which of the following PCR components is used in the Sanger method of DNA Sequencing?
#  DNA Polymerase 1
# Single-stranded DNA Molecule
# A pair of DNA primers
# dNTPs
# Correct option: dNTPs
# Quality: 2.8
# --- distractor not similar enough
# dNTPs 		 DNA Polymerase 1 		 Score: 0.0358
# Question: Which of the following PCR components is used in the Sanger method of DNA Sequencing?
#  DNA Polymerase 1
# Single-stranded DNA Molecule
# A pair of DNA primers
# dNTPs
# Correct option: dNTPs
# Quality: 2.8
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  DNA Polymerase 1
# cleaned_string:  Singlestranded DNA Molecule
# cleaned_string:   pair of DNA primers
# --- verb tense doesn't align between answer other options
# i:  13
# opt_entity:  Hydrophobic
# lemma_nouns_opt:  ['hydrophobic']
# ans_entity:  All of above
# lemma_nouns_ans:  []
# Question: The following correct statement about dietary triglyceride is
#  Hydrophobic
# Must to be emulsified to digest
# Carried by a lipoprotein to transport
# All of above
# Correct option: All of above
# Quality: 2.45
# --- distractor not similar enough
# All of above 		 Hydrophobic 		 Score: 0.1230
# Question: The following correct statement about dietary triglyceride is
#  Hydrophobic
# Must to be emulsified to digest
# Carried by a lipoprotein to transport
# All of above
# Correct option: All of above
# Quality: 2.45
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- Question stem does not contain a question
# cleaned_string:  Hydrophobic
# cleaned_string:  Must to be emulsified to digest
# cleaned_string:  Carried by a lipoprotein to transport
# --- verb tense doesn't align between answer other options
# i:  14
# Question: Why do we need RNA polymerase II in the highest amount?
#  RNA polymerase II makes tRNA in eukaryotic cells. This is needed for enhancer sequences.
# RNA polymerase II makes mRNA precursors and snRNA in eukaryotic cells. All protein-encoding genes are transcribed by RNA polymerase II.
# RNA polymerase II makes mRNA and tRNA in eukaryotic cells. It has an editing function and proofreads the last nucleotide added.
# RNA polymerase II makes tRNA and rRNA in eukaryotic cells. It fills in the gaps in a lagging strand.
# Correct option: RNA polymerase II makes mRNA precursors and snRNA in eukaryotic cells. All protein-encoding genes are transcribed by RNA polymerase II.
# Quality: 2.83
# repeating_nouns_synonyms:  ['rna', 'cell', 'polymerase', 'ii']
# repeating_nouns_synonyms:  ['rna', 'cell', 'polymerase', 'ii']
# repeating_nouns_synonyms:  ['rna', 'cell', 'polymerase', 'ii']
# cleaned_string:  RNA polymerase II makes tRNA in eukaryotic cells This is needed for enhancer sequences
# cleaned_string:  RNA polymerase II makes mRNA and tRNA in eukaryotic cells It has an editing function and proofreads the last nucleotide added
# cleaned_string:  RNA polymerase II makes tRNA and rRNA in eukaryotic cells It fills in the gaps in a lagging strand
# i:  15
# Question: During the Krebs cycle, Isocitrate is oxidised to alpha-ketoglutarate and a number of products are produced. In regards to this process, which of the following is correct?
#  A
# B
# C
# D
# Correct option: B
# Quality: 3.0
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:
# cleaned_string:
# cleaned_string:
# i:  16
# Question: Which following step is correct order of converting mRNA into a cDNA?
#  A
# B
# C
# D
# Correct option: C
# Quality: 3.22
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:
# cleaned_string:
# cleaned_string:
# i:  17
# Question: Which of the following is FALSE about glycogen with regards to exercise?
#  In aerobic conditions glycogen undergoes various reactions to form ATP.
# In anaerobic conditions glycogen undergoes various reactions to form lactate.
# Glycogen breakdown in exercising muscle is activated by insulin.
# A person decreases glycogen storage in their body when they exercise.
# Correct option: Glycogen breakdown in exercising muscle is activated by insulin.
# Quality: 2.5
# repeating_nouns_synonyms:  ['glycogen']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  glycogen
# cleaned_string:  In aerobic conditions glycogen undergoes various reactions to form ATP
# cleaned_string:  In anaerobic conditions glycogen undergoes various reactions to form lactate
# cleaned_string:   person decreases glycogen storage in their body when they exercise
# --- verb tense doesn't align between answer other options
# i:  18
# Question: The figure below shows some liver and VLDL process diagrams, but some steps are missing. Which of the following substances correctly corresponds to A, B, and C?
#  A is VLDL. B is LDL. C is HDL.
# A is LDL. B is Chylomicron remnants. C is VLDL.
# A is VLDL. B is Chylomicron remnants. C is LDL
# A is VLDL. B is LDL C is Chylomicron remnants.
# Correct option: A is VLDL. B is Chylomicron remnants. C is LDL
# Quality: 2.89
# repeating_nouns_synonyms:  ['ldl', 'vldl', 'c', 'b']
# repeating_nouns_synonyms:  ['vldl', 'remnant', 'c', 'b', 'ldl', 'chylomicron']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  remnant
# cleaned_string:   is VLDL  is LDL  is HDL
# cleaned_string:   is LDL  is Chylomicron remnants  is VLDL
# cleaned_string:   is VLDL  is LDL  is Chylomicron remnants
# i:  19
# Question: In low-intensity exercise,why does the predominant energy source for oxidation change from glucose to fatty acids?
#  All glucose stores will deplete very quickly and hence fatty acids must come in to replace glucose.
# Fatty acids inhibit glucose oxidation by inhibiting pyruvate dehydrogenase.
# Lactate levels are too low to be converted to pyruvate and fatty acids are used instead.
# Fatty acids are prioritised so glucose stores are conserved for the brain and vital muscles.
# Correct option: Fatty acids inhibit glucose oxidation by inhibiting pyruvate dehydrogenase.
# Quality: 2.57
# repeating_nouns_synonyms:  ['acid']
# repeating_nouns_synonyms:  ['acid']
# repeating_nouns_synonyms:  ['fatty', 'acid']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  fatty
# cleaned_string:  All glucose stores will deplete very quickly and hence fatty acids must come in to replace glucose
# cleaned_string:  Lactate levels are too low to be converted to pyruvate and fatty acids are used instead
# cleaned_string:  Fatty acids are prioritised so glucose stores are conserved for the brain and vital muscles
# --- verb tense doesn't align between answer other options
# i:  20
# Question: Chylomicrons are lipoprotein particles which carry remnants upon arrival at the liver. Which of the following is CORRECT in relation to remnant composition?
#  Chylomicron remnants contain an abundance of dietary fat which is transported into the liver.
# Chylomicron remnants enter liver exocytosis.
# The human liver creates HDLs from remnants left behind by chylomicrons.
# When fat is removed from chylomicrons, they leave cholesterol poor remnants upon arrival at the liver.
# Correct option: Chylomicron remnants contain an abundance of dietary fat which is transported into the liver.
# Quality: 2.9
# repeating_nouns_synonyms:  ['chylomicron', 'remnant']
# repeating_nouns_synonyms:  ['remnant', 'chylomicron', 'liver']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  liver
# cleaned_string:  Chylomicron remnants enter liver exocytosis
# cleaned_string:  The human liver creates HDLs from remnants left behind by chylomicrons
# cleaned_string:  When fat is removed from chylomicrons they leave cholesterol poor remnants upon arrival at the liver
# --- verb tense doesn't align between answer other options
# i:  21
# Question: Which of the following statements is the most correct about the supplement of energy?
#  When a person exercises, glucagon is secreted, and glycogen is converted into glucose in the kidney first, which is used to fuel the muscles.
# The concentration of glucagon increases, fat breaks down to fatty acids in adipose tissue. Thus fatty acids are the major source of energy for skeletal muscle during exercise.
# Glycogen acts like a buffer because the controlled breakdown of glycogen contributes to maintaining a blood-glucose level.
# Glucose is the only energy source used by the brain. When blood glucose level decreases, the glycogen stored in the brain breaks down to glucose to supply energy for the brain.
# Correct option: Glycogen acts like a buffer because the controlled breakdown of glycogen contributes to maintaining a blood-glucose level.
# Quality: 2.63
# repeating_nouns_synonyms:  ['glycogen']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  glycogen
# --- absolute word in question stem
# --- This might be a K-type question
# --- verb tense doesn't align between answer other options
# i:  22
# Question: C5-21 Which of the following regarding cholesterol's role in a cell membrane is incorrect ?
#  Adding cholesterol to a membrane with too many unsaturated fatty acids will decrease its fluidity.
# Cholesterol acts as a membrane fluidity 'buffer'.
# Adding cholesterol to a membrane with lots of saturated fatty acids will increase its solidity.
# Cholesterol helps keep the membrane impermeable to some water soluble molecules.
# Correct option: Adding cholesterol to a membrane with lots of saturated fatty acids will increase its solidity.
# Quality: 2.86
# repeating_nouns_synonyms:  ['acid', 'cholesterol']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  acid
# cleaned_string:  Adding cholesterol to a membrane with too many unsaturated fatty acids will decrease its fluidity
# cleaned_string:  Cholesterol acts as a membrane fluidity buffer
# cleaned_string:  Cholesterol helps keep the membrane impermeable to some water soluble molecules
# --- verb tense doesn't align between answer other options
# i:  23
# Question: What is the major function of pyruvate carboxylase in relation to anaplerosis?
#  It catalyses the formation of oxaloacetate from aspartate through a transanimation reaction
# It catalyses the carboxylation of pyruvate to form oxaloacetate directly into the mitochondria, through the hydrolysis of ATP.
# It catalyses the carboxylation of pyruvate to form oxaloacetate directly into the mitochondria, without the use of ATP
# It catalyses the formation of acetyl-CoA and CO2 from pyruvate.
# Correct option: It catalyses the carboxylation of pyruvate to form oxaloacetate directly into the mitochondria, through the hydrolysis of ATP.
# Quality: 3.0
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['atp', 'mitochondrion', 'form']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  atp
# cleaned_string:  It catalyses the formation of oxaloacetate from aspartate through a transanimation reaction
# cleaned_string:  It catalyses the carboxylation of pyruvate to form oxaloacetate directly into the mitochondria without the use of ATP
# cleaned_string:  It catalyses the formation of acetylCoA and CO2 from pyruvate
# i:  24
# Question: Through metabolic processes glucose can be produced or broken down. Fill in the boxes with the appropriate words :
#  1)Gluconeogenesis 2) PFK - 1 3) Fructose 1,6- bisphosphate 4) Glycolysis
# 1) Glycolysis 2) PFK - 1 3) Fructose 1,6- bisphosphate 4) Gluconeogenesis
# 1) Glycolysis 2) PFK - 2 3) Fructose 2,6 - bisphosphate 4) Glucoengenesis
# 1) Gluceogenesis 2) PFK - 1 3) Fructose 2,6 - bisphosphate 4)Glycolysis
# Correct option: 1) Glycolysis 2) PFK - 1 3) Fructose 1,6- bisphosphate 4) Gluconeogenesis
# Quality: 2.73
# repeating_nouns_synonyms:  ['fructose', 'glycolysis']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  fructose
# --- This might be a K-type question
# i:  25
# Question: Which of the following statements is FALSE. In amino acid processing:
#  An alpha-keto acid obtains an amine group stripped from an amino acid
# An alpha-keto group pairs with an amino acid to be removed via the urea cycle
# An alpha-keto acid converts into an amino acid
# An alpha-keto acid is formed for use in gluconeogenesis
# Correct option: An alpha-keto group pairs with an amino acid to be removed via the urea cycle
# Quality: 2.47
# repeating_nouns_synonyms:  ['group', 'acid', 'amino']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  group
# cleaned_string:  An alphaketo acid obtains an amine group stripped from an amino acid
# cleaned_string:  An alphaketo acid converts into an amino acid
# cleaned_string:  An alphaketo acid is formed for use in gluconeogenesis
# --- verb tense doesn't align between answer other options
# i:  26
# Question: Which one of the situations would not happen during extended starvation?
#  Amino acids that were breaking down from protein can be used ingluconeogenesis.
# Breaking down of proteins as there isn&rsquo;t enough glucose for body tissues to use, this process of proteolysis is triggered by low insulin level of the body.
# Starvation triggers equilibrium of fuel metabolism because our body uses the same amount of ketone bodies and glucose for energy under normal conditions without starvation.
# Fatty acids as a fuel of energy that was stored in adipose tissue during starvation will increase over time, and then being provided to glycerol to go into the liver.
# Correct option: Starvation triggers equilibrium of fuel metabolism because our body uses the same amount of ketone bodies and glucose for energy under normal conditions without starvation.
# Quality: 2.22
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['body']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  body
# cleaned_string:  Amino acids that were breaking down from protein can be used ingluconeogenesis
# cleaned_string:  Breaking down of proteins as there isnrsquot enough glucose for body tissues to use this process of proteolysis is triggered by low insulin level of the body
# cleaned_string:  Fatty acids as a fuel of energy that was stored in adipose tissue during starvation will increase over time and then being provided to glycerol to go into the liver
# --- verb tense doesn't align between answer other options
# i:  27
# opt_entity:  Spontaneous decarboxylation of ketone bodies to acetone
# lemma_nouns_opt:  ['decarboxylation', 'ketone', 'acetone']
# ans_entity:  A block in glucose transport into tissues
# lemma_nouns_ans:  ['block', 'glucose', 'transport', 'tissue']
# Question: Which is not a fundamental symptom of diabetes?
#  Uncontrolled lipolysis and proteolysis
# Spontaneous decarboxylation of ketone bodies to acetone
# A block in glucose transport into tissues
# Increased of hepatic glucose production
# Correct option: A block in glucose transport into tissues
# Quality: 2.51
# --- distractor not similar enough
# A block in glucose transport into tissues 		 Spontaneous decarboxylation of ketone bodies to acetone 		 Score: 0.1129
# Question: Which is not a fundamental symptom of diabetes?
#  Uncontrolled lipolysis and proteolysis
# Spontaneous decarboxylation of ketone bodies to acetone
# A block in glucose transport into tissues
# Increased of hepatic glucose production
# Correct option: A block in glucose transport into tissues
# Quality: 2.51
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['glucose']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  glucose
# cleaned_string:  Uncontrolled lipolysis and proteolysis
# cleaned_string:  Spontaneous decarboxylation of ketone bodies to acetone
# cleaned_string:  Increased of hepatic glucose production
# --- verb tense doesn't align between answer other options
# i:  28
# Question: Which of the following does not lead to the activation of hormone-sensitive lipase and fatty acid release in the bloodstream?
#  Glucagon binding to glucagon receptors phosphorylates PKA to trigger phosphorylation cascade
# Adenylyl cyclase is activated to produce cAMP from ATP.
# PKA phosphorylates perilipin allowing HSL to interact with fatty acids.
# PKA is activated by removing an inhibitory subunit in high cAMP concentrations
# Correct option: Glucagon binding to glucagon receptors phosphorylates PKA to trigger phosphorylation cascade
# Quality: 2.95
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- absolute word in question stem
# cleaned_string:  Adenylyl cyclase is activated to produce cAMP from ATP
# cleaned_string:  PKA phosphorylates perilipin allowing HSL to interact with fatty acids
# cleaned_string:  PKA is activated by removing an inhibitory subunit in high cAMP concentrations
# --- verb tense doesn't align between answer other options
# i:  29
# Question: You have a stock CS solution that has a specific activity of 200 U/mg protein and is in solution at 10 mg/ml. 1 Unit of enzyme activity converts 1 umol of substrate into product per minute.The extinction coefficient of the yellow product is 15 mM-1 cm-1 at 412 nm and DTNB does not absorb at this wavelength. Citrate synthase converts the acetyl CoA and oxaloacetate into citrate and CoA. The thiol group on CoA then reacts spontaneously with DTNB to give a yellow product. 200 uL of solution has a path length of 1 cm. 20 uL of a sample of homogenate gave an absorbance reading of 0.9 when added to 180 uL of buffer solution. It was incubated for 20 mins. What is the concentration of acetyl CoA in the homogenate?
#  120mM
# 3mM
# 1.2uM
# 600uM
# Correct option: 600uM
# Quality: 3.17
# --- CTTR above 4.5, text is too complex and extraneous:  4.718067676668703
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  120mM
# cleaned_string:  3mM
# cleaned_string:  12uM
# i:  30
# Question: salmon and olive oil are both good sources of unsaturated fat, however deep-fried salmon with olive oil is actually unhealthy because:
#  The high temperature harms the effectiveness of nutrients.
# The high temperature breaks some of the double bounds in the polyunsaturated fats and turns them into monosaturated fats which is unhealthy.
# The unsaturated fats is fully oxidized to saturated fats in the cooking process
# Deep-frying may increases the trans fats contents of the food.
# Correct option: Deep-frying may increases the trans fats contents of the food.
# Quality: 2.59
# repeating_nouns_synonyms:  ['nutrient']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  nutrient
# --- Question stem does not contain a question
# cleaned_string:  The high temperature harms the effectiveness of nutrients
# cleaned_string:  The high temperature breaks some of the double bounds in the polyunsaturated fats and turns them into monosaturated fats which is unhealthy
# cleaned_string:  The unsaturated fats is fully oxidized to saturated fats in the cooking process
# --- verb tense doesn't align between answer other options
# i:  31
# --- Question stem is unclear
# Question: C2-43 - Which of the following answers depicts best why creatine supplementation is useful for sprinters?
#  Creatine phosphate is able to replenish ADP to ATP, the main and preferred energy source in sprinting.
# Creatine is absorbed into the blood faster than sugars.
# Creatine and one of its main metabolites creatinine contain more harnessable energy than ATP and therefore provide a better source of fuel for sprinting.
# Creatine promotes the growth of type IIb muscles which are essential for sprinting, rather than type I muscles.
# Correct option: Creatine phosphate is able to replenish ADP to ATP, the main and preferred energy source in sprinting.
# Quality: 2.75
# repeating_nouns_synonyms:  ['creatine']
# repeating_nouns_synonyms:  ['atp', 'creatine', 'energy', 'source']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  atp
# cleaned_string:  Creatine is absorbed into the blood faster than sugars
# cleaned_string:  Creatine and one of its main metabolites creatinine contain more harnessable energy than ATP and therefore provide a better source of fuel for sprinting
# cleaned_string:  Creatine promotes the growth of type IIb muscles which are essential for sprinting rather than type I muscles
# --- verb tense doesn't align between answer other options
# i:  32
# Question: The rate of ATP synthesis is exactly matched to the rate of ATP consumption. Based on this, which effectof decreased ATP consumptionis TRUE in terms of fuel oxidation.
#  Protons permeate into the inner mitochondrial membrane due to an increased gradient.
# Proton pump activity decreases when gradient increases resulting in slowed H/e - movement down the electron transport chain.
# Proton pump activity increases when gradient increases to maintain a constant rate of H/e - movement down the electron transport chain.
# Protons continue to flow into the matrix at a steady pace regardless of the consumption of ATP.
# Correct option: Proton pump activity decreases when gradient increases resulting in slowed H/e - movement down the electron transport chain.
# Quality: 2.96
# repeating_nouns_synonyms:  ['gradient', 'proton']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  gradient
# cleaned_string:  Protons permeate into the inner mitochondrial membrane due to an increased gradient
# cleaned_string:  Proton pump activity increases when gradient increases to maintain a constant rate of He  movement down the electron transport chain
# cleaned_string:  Protons continue to flow into the matrix at a steady pace regardless of the consumption of ATP
# i:  33
# Question: Beta-Oxidation is the mechanism that breaks down fatty acids into a useable source of energy. Which of the following is FALSE inregards to the process of beta-oxidation?
#  Acetyl-CoA is formed after the fatty acyl-CoA has been stripped of its electrons and hydrogens.
# FAD and NAD are responsible for 'ripping' hydrogens and electrons from the saturated fatty acids within the cytoplasm of the cell.
# Fatty acyl-CoA is transported to the mitochondria by carnitine for oxidation.
# Triglycerides must be split by enzymes into free fatty acids and glycerol molecules before beta-oxidation can occur
# Correct option: FAD and NAD are responsible for 'ripping' hydrogens and electrons from the saturated fatty acids within the cytoplasm of the cell.
# Quality: 3.35
# repeating_nouns_synonyms:  ['electron', 'hydrogen']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  electron
# cleaned_string:  AcetylCoA is formed after the fatty acylCoA has been stripped of its electrons and hydrogens
# cleaned_string:  Fatty acylCoA is transported to the mitochondria by carnitine for oxidation
# cleaned_string:  Triglycerides must be split by enzymes into free fatty acids and glycerol molecules before betaoxidation can occur
# --- verb tense doesn't align between answer other options
# i:  34
# --- Question stem is unclear
# Question: Antiretroviral therapy (ART), are a combination of medicines that work to treat the retrovirus, HIV. Which of these options is the therapy's most likely function for the treatment of this disease?
#  Reacting with the enzyme reverse transcriptase, therefore changing HIV chemically.
# Activating the enzyme reverse transcriptase, to stimulate reverse transcription.
# Binding to the enzyme reverse transcriptase, therefore blocking HIV from making copies of itself.
# Activating the enzyme reverse transcriptase, to prevent HIV from entering the host cell.
# Correct option: Binding to the enzyme reverse transcriptase, therefore blocking HIV from making copies of itself.
# Quality: 2.69
# repeating_nouns_synonyms:  ['reverse', 'transcriptase', 'hiv']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  hiv
# --- absolute word in question stem
# --- This might be a K-type question
# i:  35
# Question: Which of the following statements is TRUE about the conversionof pyruvate to phosphoenolpyruvate and it opposite process in glycolysis?
#  Pyruvate carboxylase is stimulated byincreased transcription/translation of the gene.
# The conversion of pyruvate to phosphoenolpyruvate need pyruvate carboxylase and PEP carboxykinase.
# PEPCK is stimulated byacetyl-CoA.
# The conversion of phosphoenolpyruvate to pyruvateneed pyruvate carboxylase.
# Correct option: The conversion of pyruvate to phosphoenolpyruvate need pyruvate carboxylase and PEP carboxykinase.
# Quality: 2.54
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['conversion']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  conversion
# cleaned_string:  Pyruvate carboxylase is stimulated byincreased transcriptiontranslation of the gene
# cleaned_string:  PEPCK is stimulated byacetylCoA
# cleaned_string:  The conversion of phosphoenolpyruvate to pyruvateneed pyruvate carboxylase
# --- verb tense doesn't align between answer other options
# i:  36
# Question: An unknown sample of DNA solution is found. You would like to find the concentration of this sample, but are unsure about how to do this. You are given considerations from your lab partners, which of the following is the most true answer:
#  Producing a set of results from the unknown sample using a spectrophotometer to produce a standard curve and then finding the concentration of the sample.
# Finding the purity of the DNA sample and then using the extinction coefficient to find the concentration.
# Utilising a known sample of DNA solution to produce a standard curve and then using this to find your unknown samples concentration.
# It is not possible to find the concentration as it could be out of the spectrophotometers working range.
# Correct option: Utilising a known sample of DNA solution to produce a standard curve and then using this to find your unknown samples concentration.
# Quality: 2.62
# repeating_nouns_synonyms:  ['result', 'concentration', 'sample', 'curve']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  result
# cleaned_string:  Producing a set of results from the unknown sample using a spectrophotometer to produce a standard curve and then finding the concentration of the sample
# cleaned_string:  Finding the purity of the DNA sample and then using the extinction coefficient to find the concentration
# cleaned_string:  It is not possible to find the concentration as it could be out of the spectrophotometers working range
# i:  37
# Question: When blood glucose concentration drops below 5mM, glucagon is released by the pancreas to restore this euglycemic state. Which of the following best represents what happens when glucagon levels are high in terms of the regulatory molecule fructose 2,6-bisphosphate?
#  glucagon increases - cAMP increases - PFK2 deactivates and FBPase2 activates - F26BP decreases - inhibition of glycolysis and stimulation of gluconeogenesis
# glucagon increases - cAMP decreases - PFK2 inactivates and FBPase2 activates - F26BP decreases - inhibition of glycolysis and stimulation of gluconeogenesis
# glucagon increases - cAMP increases - both PFK2 and FBPase2 parts deactivate - F26BP decreases - inhibition of glycolysis and stimulation of gluconeogenesis
# glucagon increases - cAMP increases - both PFK2 and FBPase2 parts activate - F26BP decreases - inhibition of glycolysis and stimulation of gluconeogenesis
# Correct option: glucagon increases - cAMP increases - PFK2 deactivates and FBPase2 activates - F26BP decreases - inhibition of glycolysis and stimulation of gluconeogenesis
# Quality: 2.79
# repeating_nouns_synonyms:  ['inhibition', 'camp', 'glycolysis', 'stimulation', 'increase', 'glucagon']
# repeating_nouns_synonyms:  ['inhibition', 'camp', 'glycolysis', 'stimulation', 'increase', 'glucagon']
# repeating_nouns_synonyms:  ['inhibition', 'camp', 'glycolysis', 'stimulation', 'increase', 'glucagon']
# cleaned_string:  glucagon increases  cAMP decreases  PFK2 inactivates and FBPase2 activates  F26BP decreases  inhibition of glycolysis and stimulation of gluconeogenesis
# cleaned_string:  glucagon increases  cAMP increases  both PFK2 and FBPase2 parts deactivate  F26BP decreases  inhibition of glycolysis and stimulation of gluconeogenesis
# cleaned_string:  glucagon increases  cAMP increases  both PFK2 and FBPase2 parts activate  F26BP decreases  inhibition of glycolysis and stimulation of gluconeogenesis
# i:  38
# Question: Which of the following statements about the urea cycle is TRUE?
#  The urea cycle shares several biochemical pathways with the Kreb's cycle and produces a net increase in energy for the cell.
# The urea cycle occurs both in the cytosol and mitochondrial matrix.
# Ornithine must be synthesised de novo for every cycle of the urea cycle because it is excreted in the urine.
# Urine contains free ammonium and is therefore toxic.
# Correct option: The urea cycle occurs both in the cytosol and mitochondrial matrix.
# Quality: 2.82
# repeating_nouns_synonyms:  ['cycle']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  cycle
# --- absolute word in question stem
# cleaned_string:  The urea cycle shares several biochemical pathways with the Krebs cycle and produces a net increase in energy for the cell
# ...
# cleaned_string:  increase to accomodate for increased ADP usage by other cells
# --- verb tense doesn't align between answer other options
# i:  388
# Question: C2-25 Kevin is waiting for his friend at Redfern station so they can walk to university of together. However, he gets a text from his friend saying he decided to skip his lectures. Kevin starts walking at a nice light paste to ensure he makes his class on time. Which of the following is true in regards to Kevin's level of exercise and metabolism?
#  Kevin is doing gentle exercise. As he continues doing exercise that rate of glucose uptake into his muscles will increases. To ensure there is enough glucose uptake his GLUT 2 transporters move to the surface of the membrane to allow the glucose to translocate into the muscle cells.
# Kevin is doing intense exercise. As he continues exercising the rate of fatty acid and glucose utilisation increases. However, this is not sufficient in providing energy resulting in glycogen being utilised and broken down into glucose.
# Kevin is doing gentle exercise. As he continues exercising the rate of glucose uptake will increase. To ensure there is enough glucose uptake his GLUT 4 transporters moveto the surface of the membrane to allow the translocation of glucose.
# Kevin is doing medium exercise. As he continues exercising the rate of fatty acid utilisation increases. To ensure there is enough fatty acid uptake his GLUT 1 transporters move across the membrane of white adipose tissue and attaches to fatty acids bring it into the cell.
# Correct option: Kevin is doing gentle exercise. As he continues exercising the rate of glucose uptake will increase. To ensure there is enough glucose uptake his GLUT 4 transporters moveto the surface of the membrane to allow the translocation of glucose.
# Quality: 2.65
# repeating_nouns_synonyms:  ['exercise', 'glut', 'increase', 'membrane', 'surface', 'rate', 'transporter']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  glut
# --- absolute word in question stem
# cleaned_string:  Kevin is doing gentle exercise As he continues doing exercise that rate of glucose uptake into his muscles will increases To ensure there is enough glucose uptake his GLUT 2 transporters move to the surface of the membrane to allow the glucose to translocate into the muscle cells
# cleaned_string:  Kevin is doing intense exercise As he continues exercising the rate of fatty acid and glucose utilisation increases However this is not sufficient in providing energy resulting in glycogen being utilised and broken down into glucose
# cleaned_string:  Kevin is doing medium exercise As he continues exercising the rate of fatty acid utilisation increases To ensure there is enough fatty acid uptake his GLUT 1 transporters move across the membrane of white adipose tissue and attaches to fatty acids bring it into the cell
# i:  389
# --- Question stem is unclear
# Question: Which of the one of the following statements about glucose is false ?
#  More energy is stored in triglycerides compared to glucose.
# Acetyl-CoA can be converted back into pyruvate to be re-stored as glucose.
# The brain uses glucose as its primary fuel source under normal conditions.
# Glycogen is stored in the liver, which is then broken down into pyruvate during glycolysis.
# Correct option: Acetyl-CoA can be converted back into pyruvate to be re-stored as glucose.
# Quality: 3.0
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- The answer entity is not found in any other options:  ORG
# cleaned_string:  More energy is stored in triglycerides compared to glucose
# cleaned_string:  The brain uses glucose as its primary fuel source under normal conditions
# cleaned_string:  Glycogen is stored in the liver which is then broken down into pyruvate during glycolysis
# --- verb tense doesn't align between answer other options
# i:  390
# Question: In the first step of payoff phase of glycolysis, hydrogens are ripped out by a proton accepting coenzyme forming an energetic molecule which then undergoes reactions to form ATP. Which of the following options is correct in relation to the above statement?
#  The coenzyme is FAD which is converted to FADH2 The ATP forming reactions are substrate-level phosphorylation
# The coenzyme is FAD which is converted to FADH2 The ATP forming reactions are oxidative phosphorylation
# The coenzyme is NAD+ which is converted to NADH The ATP forming reactions are substrate-level phosphorylation
# The coenzyme is NAD+ which is converted to NADH The ATP forming reactions are oxidative phosphorylation
# Correct option: The coenzyme is NAD+ which is converted to NADH The ATP forming reactions are substrate-level phosphorylation
# Quality: 3.26
# repeating_nouns_synonyms:  ['atp', 'coenzyme', 'reaction']
# repeating_nouns_synonyms:  ['atp', 'coenzyme', 'reaction']
# repeating_nouns_synonyms:  ['atp', 'coenzyme', 'reaction']
# cleaned_string:  The coenzyme is FAD which is converted to FADH2 The ATP forming reactions are substratelevel phosphorylation
# cleaned_string:  The coenzyme is FAD which is converted to FADH2 The ATP forming reactions are oxidative phosphorylation
# cleaned_string:  The coenzyme is NAD which is converted to NADH The ATP forming reactions are oxidative phosphorylation
# i:  391
# Question: Type 1 diabetes is an autoimmune disease that is more prevalent in a younger age group. Which of the following sentences correctly describes Type 1 diabetes ? (a) The body creates antigens against beta cells in the islets of Langerhans in the pancreas. (b) Due to the autoimmune attack, the beta cells become resistant to insulin and cannot respond properly to increased BGL.
#  (a) is correct and (b) is incorrect
# Both (a) and (b) are incorrect
# (a) is incorrect and (b) is correct
# Both (a) and (b) are correct
# Correct option: Both (a) and (b) are incorrect
# Quality: 3.0
# repeating_nouns_synonyms:  ['incorrect', 'b']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  incorrect
# cleaned_string:  a is correct and b is incorrect
# cleaned_string:  a is incorrect and b is correct
# cleaned_string:  Both a and b are correct
# i:  392
# Question: [Table 8] Adding the following molecule into a polymerisation process will result in which of the following:
#  All reactions will terminate immediately when ddATP is added.
# Reactions will terminate after a reaching a certain amount of time, resulting in incomplete products that are the same length.
# Some reactions will stop at random times after the addition of the ddATP, resulting in a range of different products that also vary in length.
# No reactions will terminate, however some reactions will mix together, and random products will be formed.
# Correct option: Some reactions will stop at random times after the addition of the ddATP, resulting in a range of different products that also vary in length.
# Quality: 2.83
# repeating_nouns_synonyms:  ['reaction']
# repeating_nouns_synonyms:  ['length', 'product', 'time', 'reaction']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  length
# cleaned_string:  All reactions will terminate immediately when ddATP is added
# cleaned_string:  Reactions will terminate after a reaching a certain amount of time resulting in incomplete products that are the same length
# cleaned_string:  No reactions will terminate however some reactions will mix together and random products will be formed
# i:  393
# Question: Scientists collected some blood samples from individuals who have been starving for more than 30 days to measure the plasma level of glucose, fatty acids and ketone bodies as shown in the graph below. Which of the following is NOT the reason whystarving for more than 30 daysis unsustainable?
#  Other organs still need constant glucose supply as their main energy source from proteolysis
# Ketone bodies can spontaneous decarboxylate acetoacetate to acetone which is a useless molecule
# The break down of protein can only generate 25% glucose (1g protein= 1/4 g glucose)
# Depletion of protein from tissue compromised immune system
# Correct option: The break down of protein can only generate 25% glucose (1g protein= 1/4 g glucose)
# Quality: 2.76
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['protein']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  protein
# --- absolute word in question stem
# cleaned_string:  Other organs still need constant glucose supply as their main energy source from proteolysis
# cleaned_string:  Ketone bodies can spontaneous decarboxylate acetoacetate to acetone which is a useless molecule
# cleaned_string:  Depletion of protein from tissue compromised immune system
# --- verb tense doesn't align between answer other options
# i:  394
# Question: Fructose 2,6 bisphosphate (F26BP) is a metabolite essential in regulating the second step of gluconeogenesis. How does F26BP regulate PFK and F16BPase?
#  It stimulates and inhibits PFK-2 and FBPase-2 which control its regulation.
# It binds to their active sites to activate the targets.
# It allosterically alters the affinity of the enzymes for their substrates.
# It does not regulate PFK and F16BPase.
# Correct option: It allosterically alters the affinity of the enzymes for their substrates.
# Quality: 2.74
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- absolute word in question stem
# cleaned_string:  It stimulates and inhibits PFK2 and FBPase2 which control its regulation
# cleaned_string:  It binds to their active sites to activate the targets
# cleaned_string:  It does not regulate PFK and F16BPase
# --- verb tense doesn't align between answer other options
# i:  395
# Question: A Type 1 Diabetic hasn't administered insulin for an extended period of time. How might this affect lipogenesis?
#  Pyruvate dehydrogenase performance increases, creating a blockage due to acetyl-CoA overproduction.
# Triglycerides are falsely synthesized into diglycerides, preventing energy storage.
# Limits expression of GLUT4 receptors, hindering glucose uptake by adipocytes.
# Hydrolysis begins to occur, converting triglycerides into energy.
# Correct option: Limits expression of GLUT4 receptors, hindering glucose uptake by adipocytes.
# Quality: 2.93
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Pyruvate dehydrogenase performance increases creating a blockage due to acetylCoA overproduction
# cleaned_string:  Triglycerides are falsely synthesized into diglycerides preventing energy storage
# cleaned_string:  Hydrolysis begins to occur converting triglycerides into energy
# --- verb tense doesn't align between answer other options
# i:  396
# Question: Which of the following is NOT involved in the process of lipolysis in white adipose tissue?
#  Dephosphorylated hormone sensitive lipase converts triacylglycerol into fatty acids only.
# Phosphorylated hormone sensitive lipase converts triacylglycerol into fatty acid and glycerol.
# Protein Kinase A phosphorylates perilipin to allow the activated hormone sensitive lipase to interact with fat.
# Glucagon initiates lipolysis by increasing cyclic AMP activity.
# Correct option: Dephosphorylated hormone sensitive lipase converts triacylglycerol into fatty acids only.
# Quality: 3.06
# repeating_nouns_synonyms:  ['acid', 'convert', 'lipase']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  acid
# --- absolute word in question stem
# cleaned_string:  Phosphorylated hormone sensitive lipase converts triacylglycerol into fatty acid and glycerol
# cleaned_string:  Protein Kinase  phosphorylates perilipin to allow the activated hormone sensitive lipase to interact with fat
# cleaned_string:  Glucagon initiates lipolysis by increasing cyclic AMP activity
# --- verb tense doesn't align between answer other options
# i:  397
# opt_entity:  None of the above are true.
# lemma_nouns_opt:  ['none']
# ans_entity:  ACC activity is regulated by the phosphorylation of serine residues, and when the organism is under stress, ACC activity decreases.
# lemma_nouns_ans:  ['acc', 'activity', 'phosphorylation', 'serine', 'residue', 'organism', 'stress', 'acc', 'activity', 'decrease']
# Question: Consider these statements. Select the statement that is most accurate.
#  Acetyl CoA is somewhat stimulated by insulin. Insulin levels need to reach a certain level before it can stimulate acetyl CoA.
# If insulin is not present, then ACC can still be stimulated by [citrate]. When [citrate] is very low, ACC can be stimulated.
# ACC activity is regulated by the phosphorylation of serine residues, and when the organism is under stress, ACC activity decreases.
# None of the above are true.
# Correct option: ACC activity is regulated by the phosphorylation of serine residues, and when the organism is under stress, ACC activity decreases.
# Quality: 2.58
# --- none of the above
# Question: Consider these statements. Select the statement that is most accurate.
#  Acetyl CoA is somewhat stimulated by insulin. Insulin levels need to reach a certain level before it can stimulate acetyl CoA.
# If insulin is not present, then ACC can still be stimulated by [citrate]. When [citrate] is very low, ACC can be stimulated.
# ACC activity is regulated by the phosphorylation of serine residues, and when the organism is under stress, ACC activity decreases.
# None of the above are true.
# Correct option: ACC activity is regulated by the phosphorylation of serine residues, and when the organism is under stress, ACC activity decreases.
# Quality: 2.58
# --- none of the above
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['acc']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  acc
# cleaned_string:  Acetyl CoA is somewhat stimulated by insulin Insulin levels need to reach a certain level before it can stimulate acetyl CoA
# cleaned_string:  If insulin is not present then ACC can still be stimulated by citrate When citrate is very low ACC can be stimulated
# cleaned_string:  None of the above are true
# --- vague word in question stem
# i:  398
# --- Question stem is unclear
# Question: ATP is considered an ideal energy currency within all cells in our bodies. which of the following statement is not correct?
#  Within the different type of cells, the ATP concentrations are reasonable variable, giving an average of 5mM.
# it is the terminal phosphate group in the ATP that is being ripped off when ATP is hydrolysed, releasing energy.
# ATP has the highest phosphorylating potential due to the2 high-energy phosphodiester bonds within an ATP molecule.
# ATP is a very stable molecule and it will not spontaneously disintegrate without doing work.
# Correct option: ATP has the highest phosphorylating potential due to the2 high-energy phosphodiester bonds within an ATP molecule.
# Quality: 2.79
# repeating_nouns_synonyms:  ['atp']
# repeating_nouns_synonyms:  ['atp']
# repeating_nouns_synonyms:  ['atp', 'molecule']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  molecule
# cleaned_string:  Within the different type of cells the ATP concentrations are reasonable variable giving an average of 5mM
# cleaned_string:  it is the terminal phosphate group in the ATP that is being ripped off when ATP is hydrolysed releasing energy
# cleaned_string:  ATP is a very stable molecule and it will not spontaneously disintegrate without doing work
# --- verb tense doesn't align between answer other options
# i:  399
# ambiguous_unclear_information :  40
# implausible_distractors :  29
# none_of_the_above :  7
# longest_answer_correct :  20
# gratuitous_information_in_stem :  23
# true_or_false :  59
# avoid_convergence_cues :  269
# avoid_logical_cues :  20
# all_of_the_above :  1
# fill_in_the_blank :  29
# absolute_terms :  110
# word_repeats_in_stem_and_correct_answer :  6
# unfocused_stem :  36
# complex_k_type :  80
# grammatical_cues_in_stem :  197
# lost_sequence :  1
# vague_terms :  9
# negative_worded_stem :  82

# %%
# Calculate the correlation matrix
corr_matrix = peerwise_results.corr()

# Number of tests to conduct
num_tests = 5

# Significance level (alpha)
alpha = 0.05

# Bonferroni corrected significance level
bonferroni_alpha = alpha / num_tests

# Print the correlation matrix
print(f"Bonferroni corrected alpha: {bonferroni_alpha}")
corr_matrix
# Out:
# Bonferroni corrected alpha: 0.01
#                                          ambiguous_unclear_information  \
# ambiguous_unclear_information                                 1.000000
# implausible_distractors                                       0.027856
# none_of_the_above                                             0.093918
# longest_answer_correct                                       -0.009219
# gratuitous_information_in_stem                                0.002034
# true_or_false                                                 0.038109
# avoid_convergence_cues                                       -0.049504
# avoid_logical_cues                                            0.117052
# all_of_the_above                                             -0.023956
# fill_in_the_blank                                             0.002034
# absolute_terms                                               -0.046575
# word_repeats_in_stem_and_correct_answer                       0.004307
# unfocused_stem                                               -0.043890
# complex_k_type                                               -0.041221
# grammatical_cues_in_stem                                      0.052327
# lost_sequence                                                      NaN
# vague_terms                                                  -0.054114
# more_than_one_correct                                         0.000206
# negative_worded_stem                                          0.032566
# qid                                                          -0.040438
# courseid                                                     -0.042121
# quality                                                       0.109842
#
#                                          implausible_distractors  \
# ambiguous_unclear_information                           0.027856
# implausible_distractors                                 1.000000
# none_of_the_above                                      -0.040561
# longest_answer_correct                                  0.105541
# gratuitous_information_in_stem                          0.045466
# true_or_false                                          -0.029022
# avoid_convergence_cues                                 -0.204681
# avoid_logical_cues                                     -0.084866
# all_of_the_above                                       -0.023300
# fill_in_the_blank                                       0.005844
# absolute_terms                                         -0.054653
# word_repeats_in_stem_and_correct_answer                 0.006961
# unfocused_stem                                         -0.009519
# complex_k_type                                         -0.147433
# grammatical_cues_in_stem                                0.105275
# lost_sequence                                                NaN
# vague_terms                                             0.001350
# more_than_one_correct                                  -0.067654
# negative_worded_stem                                    0.083610
# qid                                                    -0.014047
# courseid                                               -0.018423
# quality                                                 0.175869
#
#                                          none_of_the_above  \
# ambiguous_unclear_information                     0.093918
# implausible_distractors                          -0.040561
# none_of_the_above                                 1.000000
# longest_answer_correct                            0.060444
# gratuitous_information_in_stem                   -0.027558
# true_or_false                                     0.073101
# avoid_convergence_cues                            0.046295
# avoid_logical_cues                               -0.031863
# all_of_the_above                                 -0.008748
# fill_in_the_blank                                -0.027558
# absolute_terms                                    0.051478
# word_repeats_in_stem_and_correct_answer          -0.018722
# unfocused_stem                                    0.109886
# complex_k_type                                   -0.000275
# grammatical_cues_in_stem                          0.033183
# lost_sequence                                          NaN
# vague_terms                                      -0.019760
# more_than_one_correct                             0.003086
# negative_worded_stem                             -0.011718
# qid                                              -0.090980
# courseid                                         -0.086918
# quality                                          -0.026564
#
#                                          longest_answer_correct  \
# ambiguous_unclear_information                         -0.009219
# implausible_distractors                                0.105541
# none_of_the_above                                      0.060444
# longest_answer_correct                                 1.000000
# gratuitous_information_in_stem                        -0.053874
# true_or_false                                          0.196816
# avoid_convergence_cues                                -0.055594
# avoid_logical_cues                                    -0.016988
# all_of_the_above                                      -0.017102
# fill_in_the_blank                                     -0.053874
# absolute_terms                                         0.005584
# word_repeats_in_stem_and_correct_answer                0.111283
# unfocused_stem                                        -0.034209
# complex_k_type                                        -0.108213
# grammatical_cues_in_stem                               0.050220
# lost_sequence                                               NaN
# vague_terms                                           -0.038631
# more_than_one_correct                                 -0.015905
# negative_worded_stem                                   0.149126
# qid                                                   -0.034584
# courseid                                              -0.034840
# quality                                                0.056293
#
#                                          gratuitous_information_in_stem  \
# ambiguous_unclear_information                                  0.002034
# implausible_distractors                                        0.045466
# none_of_the_above                                             -0.027558
# longest_answer_correct                                        -0.053874
# gratuitous_information_in_stem                                 1.000000
# true_or_false                                                 -0.087275
# avoid_convergence_cues                                         0.038447
# avoid_logical_cues                                            -0.009104
# all_of_the_above                                              -0.015830
# fill_in_the_blank                                              0.005387
# absolute_terms                                                 0.004012
# word_repeats_in_stem_and_correct_answer                       -0.033880
# unfocused_stem                                                -0.068063
# complex_k_type                                                 0.088680
# grammatical_cues_in_stem                                      -0.096994
# lost_sequence                                                       NaN
# vague_terms                                                   -0.035759
# more_than_one_correct                                         -0.029686
# negative_worded_stem                                           0.032171
# qid                                                            0.197406
# courseid                                                       0.197992
# quality                                                       -0.115811
#
#                                          true_or_false  \
# ambiguous_unclear_information                 0.038109
# implausible_distractors                      -0.029022
# none_of_the_above                             0.073101
# longest_answer_correct                        0.196816
# gratuitous_information_in_stem               -0.087275
# true_or_false                                 1.000000
# avoid_convergence_cues                        0.050957
# avoid_logical_cues                           -0.039983
# all_of_the_above                             -0.027704
# fill_in_the_blank                            -0.052607
# absolute_terms                                0.123083
# word_repeats_in_stem_and_correct_answer       0.040150
# unfocused_stem                               -0.092676
# complex_k_type                               -0.096315
# grammatical_cues_in_stem                      0.174060
# lost_sequence                                      NaN
# vague_terms                                  -0.015350
# more_than_one_correct                         0.017150
# negative_worded_stem                          0.349515
# qid                                          -0.054649
# courseid                                     -0.051627
# quality                                       0.044058
#
#                                          avoid_convergence_cues  \
# ambiguous_unclear_information                         -0.049504
# implausible_distractors                               -0.204681
# none_of_the_above                                      0.046295
# longest_answer_correct                                -0.055594
# gratuitous_information_in_stem                         0.038447
# true_or_false                                          0.050957
# avoid_convergence_cues                                 1.000000
# avoid_logical_cues                                    -0.051600
# all_of_the_above                                       0.051447
# fill_in_the_blank                                     -0.011002
# absolute_terms                                         0.198701
# word_repeats_in_stem_and_correct_answer               -0.031738
# unfocused_stem                                         0.013766
# complex_k_type                                        -0.167382
# grammatical_cues_in_stem                               0.184300
# lost_sequence                                               NaN
# vague_terms                                            0.116214
# more_than_one_correct                                 -0.154928
# negative_worded_stem                                  -0.048331
# qid                                                   -0.016716
# courseid                                              -0.014276
# quality                                               -0.097631
#
#                                          avoid_logical_cues  all_of_the_above  \
# ambiguous_unclear_information                      0.117052         -0.023956
# implausible_distractors                           -0.084866         -0.023300
# none_of_the_above                                 -0.031863         -0.008748
# longest_answer_correct                            -0.016988         -0.017102
# gratuitous_information_in_stem                    -0.009104         -0.015830
# true_or_false                                     -0.039983         -0.027704
# avoid_convergence_cues                            -0.051600          0.051447
# avoid_logical_cues                                 1.000000         -0.018303
# all_of_the_above                                  -0.018303          1.000000
# fill_in_the_blank                                 -0.009104         -0.015830
# absolute_terms                                    -0.015387          0.029571
# word_repeats_in_stem_and_correct_answer           -0.039173         -0.010755
# unfocused_stem                                    -0.078696         -0.021606
# complex_k_type                                    -0.032843         -0.031797
# grammatical_cues_in_stem                          -0.006469          0.066421
# lost_sequence                                           NaN               NaN
# vague_terms                                       -0.041345         -0.011351
# more_than_one_correct                             -0.045199          0.001773
# negative_worded_stem                               0.099135         -0.035997
# qid                                                0.103182          0.125361
# courseid                                           0.106941          0.127883
# quality                                            0.032030         -0.006246
#
#                                          fill_in_the_blank  ...  \
# ambiguous_unclear_information                     0.002034  ...
# implausible_distractors                           0.005844  ...
# none_of_the_above                                -0.027558  ...
# longest_answer_correct                           -0.053874  ...
# gratuitous_information_in_stem                    0.005387  ...
# true_or_false                                    -0.052607  ...
# avoid_convergence_cues                           -0.011002  ...
# avoid_logical_cues                               -0.009104  ...
# all_of_the_above                                 -0.015830  ...
# fill_in_the_blank                                 1.000000  ...
# absolute_terms                                   -0.072398  ...
# word_repeats_in_stem_and_correct_answer           0.124624  ...
# unfocused_stem                                    0.016226  ...
# complex_k_type                                   -0.005744  ...
# grammatical_cues_in_stem                         -0.144107  ...
# lost_sequence                                          NaN  ...
# vague_terms                                      -0.035759  ...
# more_than_one_correct                            -0.100228  ...
# negative_worded_stem                              0.003057  ...
# qid                                               0.197839  ...
# courseid                                          0.202253  ...
# quality                                          -0.019416  ...
#
#                                          unfocused_stem  complex_k_type  \
# ambiguous_unclear_information                 -0.043890       -0.041221
# implausible_distractors                       -0.009519       -0.147433
# none_of_the_above                              0.109886       -0.000275
# longest_answer_correct                        -0.034209       -0.108213
# gratuitous_information_in_stem                -0.068063        0.088680
# true_or_false                                 -0.092676       -0.096315
# avoid_convergence_cues                         0.013766       -0.167382
# avoid_logical_cues                            -0.078696       -0.032843
# all_of_the_above                              -0.021606       -0.031797
# fill_in_the_blank                              0.016226       -0.005744
# absolute_terms                                -0.067117       -0.110297
# word_repeats_in_stem_and_correct_answer       -0.046241       -0.068053
# unfocused_stem                                 1.000000       -0.016684
# complex_k_type                                -0.016684        1.000000
# grammatical_cues_in_stem                      -0.055787       -0.196944
# lost_sequence                                       NaN             NaN
# vague_terms                                   -0.048805       -0.071826
# more_than_one_correct                          0.007622        0.151853
# negative_worded_stem                          -0.154772       -0.128274
# qid                                           -0.012086        0.013364
# courseid                                      -0.013998        0.012738
# quality                                        0.191475       -0.270201
#
#                                          grammatical_cues_in_stem  \
# ambiguous_unclear_information                            0.052327
# implausible_distractors                                  0.105275
# none_of_the_above                                        0.033183
# longest_answer_correct                                   0.050220
# gratuitous_information_in_stem                          -0.096994
# true_or_false                                            0.174060
# avoid_convergence_cues                                   0.184300
# avoid_logical_cues                                      -0.006469
# all_of_the_above                                         0.066421
# fill_in_the_blank                                       -0.144107
# absolute_terms                                           0.200903
# word_repeats_in_stem_and_correct_answer                  0.074583
# unfocused_stem                                          -0.055787
# complex_k_type                                          -0.196944
# grammatical_cues_in_stem                                 1.000000
# lost_sequence                                                 NaN
# vague_terms                                              0.117944
# more_than_one_correct                                   -0.088590
# negative_worded_stem                                     0.103451
# qid                                                      0.018707
# courseid                                                 0.023389
# quality                                                  0.046640
#
#                                          lost_sequence  vague_terms  \
# ambiguous_unclear_information                      NaN    -0.054114
# implausible_distractors                            NaN     0.001350
# none_of_the_above                                  NaN    -0.019760
# longest_answer_correct                             NaN    -0.038631
# gratuitous_information_in_stem                     NaN    -0.035759
# true_or_false                                      NaN    -0.015350
# avoid_convergence_cues                             NaN     0.116214
# avoid_logical_cues                                 NaN    -0.041345
# all_of_the_above                                   NaN    -0.011351
# fill_in_the_blank                                  NaN    -0.035759
# absolute_terms                                     NaN     0.136199
# word_repeats_in_stem_and_correct_answer            NaN    -0.024294
# unfocused_stem                                     NaN    -0.048805
# complex_k_type                                     NaN    -0.071826
# grammatical_cues_in_stem                           NaN     0.117944
# lost_sequence                                      NaN          NaN
# vague_terms                                        NaN     1.000000
# more_than_one_correct                              NaN     0.068076
# negative_worded_stem                               NaN    -0.041648
# qid                                                NaN    -0.022842
# courseid                                           NaN    -0.027326
# quality                                            NaN     0.012910
#
#                                          more_than_one_correct  \
# ambiguous_unclear_information                         0.000206
# implausible_distractors                              -0.067654
# none_of_the_above                                     0.003086
# longest_answer_correct                               -0.015905
# gratuitous_information_in_stem                       -0.029686
# true_or_false                                         0.017150
# avoid_convergence_cues                               -0.154928
# avoid_logical_cues                                   -0.045199
# all_of_the_above                                      0.001773
# fill_in_the_blank                                    -0.100228
# absolute_terms                                       -0.021271
# word_repeats_in_stem_and_correct_answer              -0.046794
# unfocused_stem                                        0.007622
# complex_k_type                                        0.151853
# grammatical_cues_in_stem                             -0.088590
# lost_sequence                                              NaN
# vague_terms                                           0.068076
# more_than_one_correct                                 1.000000
# negative_worded_stem                                  0.037478
# qid                                                  -0.063867
# courseid                                             -0.065334
# quality                                               0.017210
#
#                                          negative_worded_stem       qid  \
# ambiguous_unclear_information                        0.032566 -0.040438
# implausible_distractors                              0.083610 -0.014047
# none_of_the_above                                   -0.011718 -0.090980
# longest_answer_correct                               0.149126 -0.034584
# gratuitous_information_in_stem                       0.032171  0.197406
# true_or_false                                        0.349515 -0.054649
# avoid_convergence_cues                              -0.048331 -0.016716
# avoid_logical_cues                                   0.099135  0.103182
# all_of_the_above                                    -0.035997  0.125361
# fill_in_the_blank                                    0.003057  0.197839
# absolute_terms                                       0.104473  0.109413
# word_repeats_in_stem_and_correct_answer              0.048229  0.123711
# unfocused_stem                                      -0.154772 -0.012086
# complex_k_type                                      -0.128274  0.013364
# grammatical_cues_in_stem                             0.103451  0.018707
# lost_sequence                                             NaN       NaN
# vague_terms                                         -0.041648 -0.022842
# more_than_one_correct                                0.037478 -0.063867
# negative_worded_stem                                 1.000000  0.087599
# qid                                                  0.087599  1.000000
# courseid                                             0.088026  0.998657
# quality                                              0.133251  0.018725
#
#                                          courseid   quality
# ambiguous_unclear_information           -0.042121  0.109842
# implausible_distractors                 -0.018423  0.175869
# none_of_the_above                       -0.086918 -0.026564
# longest_answer_correct                  -0.034840  0.056293
# gratuitous_information_in_stem           0.197992 -0.115811
# true_or_false                           -0.051627  0.044058
# avoid_convergence_cues                  -0.014276 -0.097631
# avoid_logical_cues                       0.106941  0.032030
# all_of_the_above                         0.127883 -0.006246
# fill_in_the_blank                        0.202253 -0.019416
# absolute_terms                           0.112289 -0.000725
# word_repeats_in_stem_and_correct_answer  0.128535  0.017425
# unfocused_stem                          -0.013998  0.191475
# complex_k_type                           0.012738 -0.270201
# grammatical_cues_in_stem                 0.023389  0.046640
# lost_sequence                                 NaN       NaN
# vague_terms                             -0.027326  0.012910
# more_than_one_correct                   -0.065334  0.017210
# negative_worded_stem                     0.088026  0.133251
# qid                                      0.998657  0.018725
# courseid                                 1.000000  0.011531
# quality                                  0.011531  1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# ## Peerwise Biochemistry - 50 Questions

# %%
# #Maybe grab 10 from each: 1.5-1.99, 2.0-2.49, 2.50-2.99, 3.00-3.49, 3.50-3.99
# #It's fine in the paper to say these are higher quality and came from a different system, comparing OLI and PeerWise is not 
# #the point, it's just that even when such a system is used, problems persist with student-authored questions.
# qs = pd.read_csv('peerwise_questions.csv')
# def clean_df(fdf):
#     fdf = fdf[~fdf['question'].str.casefold().str.contains("img")]
#     columns_to_clean = ['question', 'altA', 'altB', 'altC', 'altD']

#     for cName in columns_to_clean:
#         fdf[cName] = fdf[cName].str.replace(r'<[^<>]*>', ' ', regex=True)
#         fdf[cName] = fdf[cName].apply(lambda x: re.sub("&nbsp;",  "", x))
#         fdf[cName] = fdf[cName].str.replace(' +', ' ', regex=True)
#         fdf[cName] = fdf[cName].str.strip()
        
#         fdf[fdf[cName].apply(lambda x: len(x.strip()) > 2)]
#         fdf[cName].replace('', np.nan, inplace=True)
#     fdf.dropna(subset=['altA'], inplace=True)
#     return fdf

# biochem_lowest = qs.loc[(qs['avg_rating'] < 2.0) & (qs['avg_rating'] > 1.49) & (qs['total_ratings'] > 19) & (qs['numAlts'] == 4)]
# biochem_lowest = clean_df(biochem_lowest)

# biochem_low = qs.loc[(qs['avg_rating'] < 2.5) & (qs['avg_rating'] > 1.99) & (qs['total_ratings'] > 19) & (qs['numAlts'] == 4)]
# biochem_low = clean_df(biochem_low)

# biochem_mid = qs.loc[(qs['avg_rating'] < 3.0) & (qs['avg_rating'] > 2.49) & (qs['total_ratings'] > 19) & (qs['numAlts'] == 4)]
# biochem_mid = clean_df(biochem_mid)

# biochem_high = qs.loc[(qs['avg_rating'] < 3.5) & (qs['avg_rating'] > 2.99) & (qs['total_ratings'] > 19) & (qs['numAlts'] == 4)]
# biochem_high = clean_df(biochem_high)

# biochem_highest = qs.loc[(qs['avg_rating'] > 3.49) & (qs['total_ratings'] > 19) & (qs['numAlts'] == 4)]
# biochem_highest = clean_df(biochem_highest)

# sampled_dfs = [biochem_lowest.sample(n=10), biochem_low.sample(n=10), biochem_mid.sample(n=10), biochem_high.sample(n=10), biochem_highest.sample(n=10)]
# fifty_biochem_questions = pd.concat(sampled_dfs, axis=0).reset_index()

#This uses the ones tagged by IWF
# qs = pd.read_csv('peerwise_50_questions.csv')

# peerwise_biochem_questions = []
# for index, row in qs.iterrows():
#     question = MultipleChoiceQuestion(
#         stem=row['question'],
#         options=[row['altA'], row['altB'], row['altC'], row['altD']],
#         correct_option= row['alt' + row['answer'].strip()],
#         qid = row['student'],
#         courseid = row['course'],
#         quality = row['course']
#     )
#     peerwise_biochem_questions.append(question)

# rows = []
# i = 0
# for q in peerwise_biochem_questions:
#     r = [ambiguous_unclear_information(q),
#         implausible_distractors(q),
#         none_of_the_above(q),
#         longest_answer_correct(q),
#         gratuitous_information_in_stem(q),
#         true_or_false(q),
#         avoid_convergence_cues(q),
#         avoid_logical_cues(q),
#         all_of_the_above(q),
#         fill_in_the_blank(q),
#         absolute_terms(q),
#         word_repeats_in_stem_and_correct_answer(q),
#         unfocused_stem(q),
#         complex_k_type(q),
#         grammatical_cues_in_stem(q),
#         lost_sequence(q),
#         vague_terms(q),
#         more_than_one_correct(q),
#         negative_worded_stem(q),
#         q.qid,
#         q.courseid,
#         q.quality]
#     rows.append(r)
#     i += 1
    
# columns = [
#     'ambiguous_unclear_information',
#     'implausible_distractors',
#     'none_of_the_above',
#     'longest_answer_correct',
#     'gratuitous_information_in_stem',
#     'true_or_false',
#     'avoid_convergence_cues',
#     'avoid_logical_cues',
#     'all_of_the_above',
#     'fill_in_the_blank',
#     'absolute_terms',
#     'word_repeats_in_stem_and_correct_answer',
#     'unfocused_stem',
#     'complex_k_type',
#     'grammatical_cues_in_stem',
#     'lost_sequence',
#     'vague_terms',
#     'more_than_one_correct',
#     'negative_worded_stem',
#     'qid',
#     'courseid',
#     'quality'
# ]

# peerwise_biochem_results = pd.DataFrame(rows, columns=columns)
# peerwise_biochem_results.to_csv("biochem_results_auto_iwf.csv")

# #Print the number of "Falses", which correspond to IWF, found the table across each criteria
# for c in columns:
#     print(c, ': ', (~peerwise_biochem_results[c]).values.sum())
# Out:
# Question: Which of the following is not a characteristic of an emulsion forming molecule?
#  They are amphiphilic.
# They act as detergents.
# They form dricelles.
# They are amphipatic.
# Correct option: They form dricelles.
# Quality: 1.6
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- The answer entity is not found in any other options:  ORG
# cleaned_string:  They are amphiphilic
# cleaned_string:  They act as detergents
# cleaned_string:  They are amphipatic
# --- GPT-3 believes the answer is incorrect:  They are amphipatic.   They form dricelles.
# Question: At what temperature is the DNA double helix denatured in PCR?
#  54 o C
# 95 o C
# 60 o C
# 75 o C
# Correct option: 95 o C
# Quality: 1.81
# repeating_nouns_synonyms:  ['c']
# repeating_nouns_synonyms:  ['c']
# repeating_nouns_synonyms:  ['c']
# cleaned_string:  54 o
# cleaned_string:  60 o
# cleaned_string:  75 o
# opt_entity:  Growth factors
# lemma_nouns_opt:  ['growth', 'factor']
# ans_entity:  DNA-dependent RNA polymerase
# lemma_nouns_ans:  ['rna', 'polymerase']
# Question: (Table 2)Oncogenes do not encode for:
#  Trans-membrane protein receptors
# Growth factors
# Cytoplasmic G-proteins and protein kinases
# DNA-dependent RNA polymerase
# Correct option: DNA-dependent RNA polymerase
# Quality: 1.79
# --- distractor not similar enough
# DNA-dependent RNA polymerase 		 Growth factors 		 Score: 0.0840
# Question: (Table 2)Oncogenes do not encode for:
#  Trans-membrane protein receptors
# Growth factors
# Cytoplasmic G-proteins and protein kinases
# DNA-dependent RNA polymerase
# Correct option: DNA-dependent RNA polymerase
# Quality: 1.79
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- Question stem does not contain a question
# cleaned_string:  Transmembrane protein receptors
# cleaned_string:  Growth factors
# cleaned_string:  Cytoplasmic Gproteins and protein kinases
# Question: For certain foods, the GI should be interpreted with caution because
#  low GI foods can contain lots of sucrose
# it is irrelevant to consider the GI of meat
# foods made with milk are low GI because lactose is half glucose
# the grain type used to make white bread can vary
# Correct option: it is irrelevant to consider the GI of meat
# Quality: 1.63
# repeating_nouns_synonyms:  ['gi']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  gi
# --- Question stem does not contain a question
# cleaned_string:  low GI foods can contain lots of sucrose
# cleaned_string:  foods made with milk are low GI because lactose is half glucose
# cleaned_string:  the grain type used to make white bread can vary
# --- verb tense doesn't align between answer other options
# --- GPT-3 believes the answer is incorrect:  the grain type used to make white bread can vary   it is irrelevant to consider the GI of meat
# opt_entity:  FAD uses complex II, whereas NAD uses complex I.
# lemma_nouns_opt:  ['us', 'ii', 'nad']
# ans_entity:  A,B,C are correct
# lemma_nouns_ans:  ['b', 'c']
# Question: There are 3 main differences between FAD and NAD, please consider these 3 statements shown below:
#  FAD uses complex II, whereas NAD uses complex I.
# NAD contains a enzyme active site, whereas FAD doesn't.
# The reduced form of FAD is FADH 2 , whereas NAD in reduced form doesn't
# A,B,C are correct
# Correct option: A,B,C are correct
# Quality: 1.51
# --- distractor not similar enough
# A,B,C are correct 		 FAD uses complex II, whereas NAD uses complex I. 		 Score: 0.0545
# Question: There are 3 main differences between FAD and NAD, please consider these 3 statements shown below:
#  FAD uses complex II, whereas NAD uses complex I.
# NAD contains a enzyme active site, whereas FAD doesn't.
# The reduced form of FAD is FADH 2 , whereas NAD in reduced form doesn't
# A,B,C are correct
# Correct option: A,B,C are correct
# Quality: 1.51
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- Question stem does not contain a question
# cleaned_string:  FAD uses complex II whereas NAD uses complex I
# cleaned_string:  NAD contains a enzyme active site whereas FAD doesnt
# cleaned_string:  The reduced form of FAD is FADH 2  whereas NAD in reduced form doesnt
# --- verb tense doesn't align between answer other options
# Question: Which of the following commonly perpetuated myths about diet and exercise is true:
#  Walking is the best way to lose fat as it primarily uses fatty acids after initial glucose consumption.
# Cardio is the best form of exercise for your metabolism as it increases the energy expenditure.
# Woman oxidise more fat than men during aerobic exercise
# Sprinting only utilises glycogen stores and has no impact on fatty acid metabolism
# Correct option: Woman oxidise more fat than men during aerobic exercise
# Quality: 1.98
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['exercise']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  exercise
# --- absolute word in question stem
# cleaned_string:  Walking is the best way to lose fat as it primarily uses fatty acids after initial glucose consumption
# cleaned_string:  Cardio is the best form of exercise for your metabolism as it increases the energy expenditure
# cleaned_string:  Sprinting only utilises glycogen stores and has no impact on fatty acid metabolism
# --- verb tense doesn't align between answer other options
# --- GPT-3 believes the answer is incorrect:  Sprinting only utilises glycogen stores and has no impact on fatty acid metabolism   Woman oxidise more fat than men during aerobic exercise
# --- Question stem is unclear
# Question: Antioxidant Physical exercise increases free-radical production in active skeletal muscles, responsible for oxidative damage to cells, and contributes to muscular fatigue during prolonged exercise. Free-radical is unstable, therefore highly reactive and promote oxidative damage to proteins, lipids and DNA i.e. causing oxidative damaged. This may lead to cellular dysfunction and cell death. James starts getting serious in exercise for his dreamy six-pack. He uses antioxidant supplements because he thought that with increase physical exercise and increase free-radical production in his body, he also needs to increase his antioxidant intake to &lsquo;balance things out&rsquo; as well. Also because he wants to get his dreamy six-pack as fast as possible, antioxidant will increase his endurance hence more exercise could be done in each day. What is the most likely reason that his choice of antioxidant supplement intake is a good choice/ uncalled for?
#  It is a good choice. Because without increase antioxidant consumption, it is very likely that free-radical will damage proteins, lipids and/or DNA in his body.
# It is a good choice. Because dietary antioxidant together with endogenous antioxidant system will form a united antioxidant network in muscle fibers therefore more efficient in protecting muscle against exercise-induced oxidative damage and fatigue.
# It is uncalled for. Because endogenous antioxidant will be enough to balance the free-radical produced from exercise.
# It is uncalled for. Because exercise might cause cells to produce more free-radical, but it also will produce more endogenous antioxidant, and with natural dietary antioxidant intake (e.g. in orange), there won&rsquo;t be ill effect on the body.
# Correct option: It is uncalled for. Because exercise might cause cells to produce more free-radical, but it also will produce more endogenous antioxidant, and with natural dietary antioxidant intake (e.g. in orange), there won&rsquo;t be ill effect on the body.
# Quality: 1.86
# --- CTTR above 4.5, text is too complex and extraneous:  5.421151989096865
# repeating_nouns_synonyms:  ['antioxidant', 'body', 'consumption']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  antioxidant
# --- absolute word in question stem
# cleaned_string:  It is a good choice Because without increase antioxidant consumption it is very likely that freeradical will damage proteins lipids andor DNA in his body
# cleaned_string:  It is a good choice Because dietary antioxidant together with endogenous antioxidant system will form a united antioxidant network in muscle fibers therefore more efficient in protecting muscle against exerciseinduced oxidative damage and fatigue
# cleaned_string:  It is uncalled for Because endogenous antioxidant will be enough to balance the freeradical produced from exercise
# --- GPT-3 believes the answer is incorrect:  It is uncalled for. Because endogenous antioxidant will be enough to balance the free-radical produced from exercise.   It is uncalled for. Because exercise might cause cells to produce more free-radical, but it also will produce more endogenous antioxidant, and with natural dietary antioxidant intake (e.g. in orange), there won&rsquo;t be ill effect on the body.
# opt_entity:  Initiation
# lemma_nouns_opt:  ['initiation']
# ans_entity:  Relocation
# lemma_nouns_ans:  ['relocation']
# Question: What is a process NOT used inEukaryotic translation?
#  Initiation
# Elongation
# Relocation
# Termination
# Correct option: Relocation
# Quality: 1.94
# --- distractor not similar enough
# Relocation 		 Initiation 		 Score: 0.1351
# Question: What is a process NOT used inEukaryotic translation?
#  Initiation
# Elongation
# Relocation
# Termination
# Correct option: Relocation
# Quality: 1.94
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Initiation
# cleaned_string:  Elongation
# cleaned_string:  Termination
# Question: Which of the following statements is true about the regulation of metabolic pathway?
#  Most of the metabolic pathways are not regulated
# Most of the metabolic pathways are regulated
# Regulation of metabolic pathways always involves changing the amount of enzymes
# Metabolic regulation always depends on control by hormones
# Correct option: Most of the metabolic pathways are regulated
# Quality: 1.76
# repeating_nouns_synonyms:  ['pathway']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  pathway
# --- absolute word in question stem
# cleaned_string:  Most of the metabolic pathways are not regulated
# cleaned_string:  Regulation of metabolic pathways always involves changing the amount of enzymes
# cleaned_string:  Metabolic regulation always depends on control by hormones
# --- verb tense doesn't align between answer other options
# Question: The structure of DNA is closely related to its biological function. Which of the following statements regarding the structure of DNA is correct?
#  All base pairs interact by forming three hydrogen bonds.
# DNA is comprised of nucleotide subunits each containing a base, a ribose sugar and a phosphate group.
# The double helix of DNA is stabilized by interactions between adjacent ribose sugars.
# Each DNA sequence folds into a unique and complex three-dimensional structure.
# Correct option: DNA is comprised of nucleotide subunits each containing a base, a ribose sugar and a phosphate group.
# Quality: 1.94
# repeating_nouns_synonyms:  ['base']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  base
# cleaned_string:  All base pairs interact by forming three hydrogen bonds
# cleaned_string:  The double helix of DNA is stabilized by interactions between adjacent ribose sugars
# cleaned_string:  Each DNA sequence folds into a unique and complex threedimensional structure
# --- verb tense doesn't align between answer other options
# Question: Person A is a vegan, however they do not have a large variety of food in their diet, and such has been losing an excessive amount of weight. Person B has a well rounded diet that includes meats and eggs and has been able to maintain a healthy weight. What could potentially be
#  Person A has all the required amino acids and Person B as amino acids in excess
# Both people have an excessive amount of amino acids
# Person A is lacking in amino acids, and Person B has the required amounts of amino acids
# Person A has some amino acids in excess and person B is lacking essential amino acids to gain weight
# Correct option: Person A is lacking in amino acids, and Person B has the required amounts of amino acids
# Quality: 2.32
# repeating_nouns_synonyms:  ['acid', 'person', 'a', 'b', 'amino']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  person
# --- absolute word in question stem
# cleaned_string:  Person  has all the required amino acids and Person  as amino acids in excess
# cleaned_string:  Both people have an excessive amount of amino acids
# cleaned_string:  Person  has some amino acids in excess and person  is lacking essential amino acids to gain weight
# --- verb tense doesn't align between answer other options
# Question: Mr. Green, 60, who has been told that he needs to lose weight and in particular control the cholesterol level in his blood, otherwise his health will be threatened. Which way is the best to help Mr. Green?
#  Immediately become a vegan, no more meat.
# Reduce the amount of full fat milk, butter and sausages in meals.
# Include food that contains high amount of phytosterols to inhibit cholesterol, such as walnuts, vegetable, fruits and legumes, in total at least 1 kg per day to reduce cholesterol as fast as possible.
# Most of the cholesterol is produced in the body, not from the intake of food, he just needs to change dietary habit and do more exercise, but he can keep smoking.
# Correct option: Reduce the amount of full fat milk, butter and sausages in meals.
# Quality: 2.42
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['amount']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  amount
# --- This might be a K-type question
# --- verb tense doesn't align between answer other options
# Question: Select the correct answer for the following statement. Chylomicrons are small fat globules composed of protein and lipids used to transport ____(A)_____ from the intestine to the liver via the ______(B)______. The liver is an excellent organ that plays a pivotal role in glucose uptake and regulation. A unique feature of the liver is that it contains _____(C)_____ which are very active and abundant, these transporters are used to take-up ______(D)_____ from the bloodstream. This process is also assisted by a special hexokinase called ______(E)______ which rapidly converts glucose to glucose-6-phosphate, and it is also not inhibited by a build-up of glucose-6-phosphate. An increased amount of glucose-6-phosphate can activate glycogen synthase _______(F)______ to make glycogen.
#  (A) Glucose (B) Hepatic portal vein (C) GLUT-4 transporters (D) Glucose (E) Special hexokinase (F) Only in the presence of insulin
# (A) Fatty acids (B) Hepatic portal vein (C) GLUT-2 transporters (D) Glucose (E) Glucokinase (F) Only in the presence of insulin
# (A) Fatty acids (B) Lymphatic system (C) GLUT-4 transporters (D) Glucose (E)Transglutaminase (F) Even in the absence of insulin
# (A) Fatty acids (B) Hepatic portal vein (C) GLUT-2 transporters (D) Glucose (E) Glucokinase (F) Even in the absence of insulin
# Correct option: (A) Fatty acids (B) Hepatic portal vein (C) GLUT-2 transporters (D) Glucose (E) Glucokinase (F) Even in the absence of insulin
# Quality: 2.23
# --- CTTR above 4.5, text is too complex and extraneous:  4.945353550468402
# repeating_nouns_synonyms:  ['vein', 'e', 'portal', 'd', 'f', 'c', 'hepatic', 'b', 'glucose', 'insulin', 'transporter']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  vein
# --- fill in the blank
# cleaned_string:   Glucose  Hepatic portal vein  GLUT4 transporters  Glucose  Special hexokinase  Only in the presence of insulin
# cleaned_string:   Fatty acids  Hepatic portal vein  GLUT2 transporters  Glucose  Glucokinase  Only in the presence of insulin
# cleaned_string:   Fatty acids  Lymphatic system  GLUT4 transporters  Glucose ETransglutaminase  Even in the absence of insulin
# opt_entity:  Finds information about target sequence
# lemma_nouns_opt:  ['find', 'information', 'target', 'sequence']
# ans_entity:  Uses very low amounts of DNA
# lemma_nouns_ans:  ['us', 'amount', 'dna']
# Question: Polymerase Chain Reaction is commonly used to isolate distinguish VNTRs between different people. Which of the following is an advantage of using PCR over other processes?
#  Uses very low amounts of DNA
# Finds information about target sequence
# Contamination is unlikely to occur
# All of the above
# Correct option: Uses very low amounts of DNA
# Quality: 2.38
# --- distractor not similar enough
# Uses very low amounts of DNA 		 Finds information about target sequence 		 Score: 0.0877
# Question: Polymerase Chain Reaction is commonly used to isolate distinguish VNTRs between different people. Which of the following is an advantage of using PCR over other processes?
#  Uses very low amounts of DNA
# Finds information about target sequence
# Contamination is unlikely to occur
# All of the above
# Correct option: Uses very low amounts of DNA
# Quality: 2.38
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Finds information about target sequence
# cleaned_string:  Contamination is unlikely to occur
# cleaned_string:  All of the above
# --- verb tense doesn't align between answer other options
# --- GPT-3 believes the answer is incorrect:  All of the above   Uses very low amounts of DNA
# Question: The components of a computer including the devices (such as a printer), hard-drive and RAM storage can be said to be analogous to the information storage components in a cell; the DNA, RNA and protein. Given this analogy, and thinking about which parts of the computer these cell components are similar to, choose the most correct answer from the following.
#  DNA is like the hard-drive of the computer as different computers, like every different cell in your body, contains different information stored in their DNA so they are able to perform the different purposes needed.
# While it is impossible for information to be sent directly from the hard-drive to devices such as printer, this is a point the metaphor breaks as it is possible for information to be sent from DNA directly to protein.
# Information can never flow from DNA to RNA, only from DNA to RNA in the same sense that information in the computer is coordinated from hard-drive to RAM storage and not the opposite way around.
# In the same way that there are more errors in external devices, than in the hard-drive, DNA replication is more free from errors than the process of translation.
# Correct option: In the same way that there are more errors in external devices, than in the hard-drive, DNA replication is more free from errors than the process of translation.
# Quality: 2.49
# repeating_nouns_synonyms:  ['dna']
# repeating_nouns_synonyms:  ['dna', 'device']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  device
# --- absolute word in question stem
# --- This might be a K-type question
# --- verb tense doesn't align between answer other options
# opt_entity:  1-3,biphosphoglycerate is a high energy molecule
# lemma_nouns_opt:  ['energy', 'molecule']
# ans_entity:  NADH is used in the preparatory phase but not the payoff phase
# lemma_nouns_ans:  ['nadh', 'phase', 'payoff', 'phase']
# Question: How many ATPs made in Glycolysis Which statement about glycolysis is false?
#  Two molecules of glyceraldehyde-3-phosphate are formed in thepreparatory phase. This requires two ATP molecules for energy
# NADH is used in the preparatory phase but not the payoff phase
# Pyruvate is the end product of the pay off phase. 2 ATP molecules are released in the last step of the payoff phase
# 1-3,biphosphoglycerate is a high energy molecule
# Correct option: NADH is used in the preparatory phase but not the payoff phase
# Quality: 2.3
# --- distractor not similar enough
# NADH is used in the preparatory phase but not the payoff phase 		 1-3,biphosphoglycerate is a high energy molecule 		 Score: 0.0973
# Question: How many ATPs made in Glycolysis Which statement about glycolysis is false?
#  Two molecules of glyceraldehyde-3-phosphate are formed in thepreparatory phase. This requires two ATP molecules for energy
# NADH is used in the preparatory phase but not the payoff phase
# Pyruvate is the end product of the pay off phase. 2 ATP molecules are released in the last step of the payoff phase
# 1-3,biphosphoglycerate is a high energy molecule
# Correct option: NADH is used in the preparatory phase but not the payoff phase
# Quality: 2.3
# repeating_nouns_synonyms:  ['phase']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  phase
# cleaned_string:  Two molecules of glyceraldehyde3phosphate are formed in thepreparatory phase This requires two ATP molecules for energy
# cleaned_string:  Pyruvate is the end product of the pay off phase 2 ATP molecules are released in the last step of the payoff phase
# cleaned_string:  13biphosphoglycerate is a high energy molecule
# --- GPT-3 believes the answer is incorrect:  1-3,biphosphoglycerate is a high energy molecule   NADH is used in the preparatory phase but not the payoff phase
# Question: An athlete competes in a race, sprinting at their maximum speed in the lead. However, 20 seconds through the race they notice themselves slowing down and eventually they finish in second place. Which of the below options could explain their inability to maintain their maximum speed?
#  Glycogen depleted so the body started generating ATP from creatine phosphate.
# Glycogen depleted so the only options remaining are fatty acids or blood glucose
# Insulin is produced to breakdown glucose to generate ATP following glycogen depletion.
# Creatine phosphate was depleted so the body immediately started generating ATP from fatty acids.
# Correct option: Glycogen depleted so the only options remaining are fatty acids or blood glucose
# Quality: 2.3
# repeating_nouns_synonyms:  ['glycogen']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  glycogen
# --- absolute word in question stem
# cleaned_string:  Glycogen depleted so the body started generating ATP from creatine phosphate
# cleaned_string:  Insulin is produced to breakdown glucose to generate ATP following glycogen depletion
# cleaned_string:  Creatine phosphate was depleted so the body immediately started generating ATP from fatty acids
# --- GPT-3 believes the answer is incorrect:  Creatine phosphate was depleted so the body immediately started generating ATP from fatty acids.   Glycogen depleted so the only options remaining are fatty acids or blood glucose
# opt_entity:  With no protons pumping out of the matrix there will be a lot of carrier with H/e-.
# lemma_nouns_opt:  ['proton', 'matrix', 'lot', 'carrier', 'h/e-']
# ans_entity:  An increase in fuel oxidation will lead to a decrease in oxygen consumption.
# lemma_nouns_ans:  ['increase', 'fuel', 'oxidation', 'lead', 'decrease', 'oxygen', 'consumption']
# Question: A reduction in ATP consumption will lead to a decrease in fuel oxidation. Which of the following statements relating to the above concept is incorrect?
#  A decrease in ATP hydrolysis will lead to a deceased amount of available ADP.
# A decreased in the rate of protons passing through the ATPase will lead to a lack of protons in the matrix.
# With no protons pumping out of the matrix there will be a lot of carrier with H/e-.
# An increase in fuel oxidation will lead to a decrease in oxygen consumption.
# Correct option: An increase in fuel oxidation will lead to a decrease in oxygen consumption.
# Quality: 2.31
# --- distractor not similar enough
# An increase in fuel oxidation will lead to a decrease in oxygen consumption. 		 With no protons pumping out of the matrix there will be a lot of carrier with H/e-. 		 Score: 0.1477
# Question: A reduction in ATP consumption will lead to a decrease in fuel oxidation. Which of the following statements relating to the above concept is incorrect?
#  A decrease in ATP hydrolysis will lead to a deceased amount of available ADP.
# A decreased in the rate of protons passing through the ATPase will lead to a lack of protons in the matrix.
# With no protons pumping out of the matrix there will be a lot of carrier with H/e-.
# An increase in fuel oxidation will lead to a decrease in oxygen consumption.
# Correct option: An increase in fuel oxidation will lead to a decrease in oxygen consumption.
# Quality: 2.31
# repeating_nouns_synonyms:  ['decrease', 'lead']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  decrease
# cleaned_string:   decrease in ATP hydrolysis will lead to a deceased amount of available ADP
# cleaned_string:   decreased in the rate of protons passing through the ATPase will lead to a lack of protons in the matrix
# cleaned_string:  With no protons pumping out of the matrix there will be a lot of carrier with He
# --- verb tense doesn't align between answer other options
# opt_entity:  Al of the above are false.
# lemma_nouns_opt:  ['al']
# ans_entity:  No, electricity is only made on demand from the potentialenergy stored in the reservoir.
# lemma_nouns_ans:  ['electricity', 'demand', 'potentialenergy', 'reservoir']
# Question: Metabolism in relation to a hydroelectric power station.Is a hydroelectric power station constantly releasingelectricity as water is passing through the turbine to activate the electric generator (aka is the power station constantly releasing energy)?
#  Yes, the more electricity that is produced, the faster it will reach electronic devices and speed up their functions.
# No, electricity is only made on demand from the potentialenergy stored in the reservoir.
# Yes, because the speed of electricity is reliant on the amount of electricity that is available. So the more electricity the higher the rate of energy.
# Al of the above are false.
# Correct option: No, electricity is only made on demand from the potentialenergy stored in the reservoir.
# Quality: 2.09
# --- distractor not similar enough
# No, electricity is only made on demand from the potentialenergy stored in the reservoir. 		 Al of the above are false. 		 Score: 0.1023
# Question: Metabolism in relation to a hydroelectric power station.Is a hydroelectric power station constantly releasingelectricity as water is passing through the turbine to activate the electric generator (aka is the power station constantly releasing energy)?
#  Yes, the more electricity that is produced, the faster it will reach electronic devices and speed up their functions.
# No, electricity is only made on demand from the potentialenergy stored in the reservoir.
# Yes, because the speed of electricity is reliant on the amount of electricity that is available. So the more electricity the higher the rate of energy.
# Al of the above are false.
# Correct option: No, electricity is only made on demand from the potentialenergy stored in the reservoir.
# Quality: 2.09
# repeating_nouns_synonyms:  ['electricity']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  electricity
# --- absolute word in question stem
# cleaned_string:  Yes the more electricity that is produced the faster it will reach electronic devices and speed up their functions
# cleaned_string:  Yes because the speed of electricity is reliant on the amount of electricity that is available So the more electricity the higher the rate of energy
# cleaned_string:  Al of the above are false
# Question: You are trying to create a standard curve, but accidentally take your measurements using a cuvette with a 2cm light path instead of 1cm. What impact does this increased light path have on the equation of your resulting standard curve?
#  The gradient of the curve becomes steeper, or greater, than you expected.
# The gradient of the curve becomes flatter, or less, than you expected.
# The gradient of the curve becomes inverted (i.e. negative/ slopes downward instead of upward).
# No effect.
# Correct option: The gradient of the curve becomes steeper, or greater, than you expected.
# Quality: 2.36
# repeating_nouns_synonyms:  ['gradient', 'curve']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  gradient
# cleaned_string:  The gradient of the curve becomes flatter or less than you expected
# cleaned_string:  The gradient of the curve becomes inverted ie negative slopes downward instead of upward
# cleaned_string:  No effect
# --- GPT-3 believes the answer is incorrect:  The gradient of the curve becomes flatter, or less, than you expected.   The gradient of the curve becomes steeper, or greater, than you expected.
# Question: Which of the following is FALSE about alanine?
#  During starvation, muscle proteins break down into glutamate and goes into the blood directly
# Alanine carries amine group into liver for regeneration of glucose
# Branched chain amino acids are used to synthesize alanine
# Alanine transforms into alpha-keto acid during transamination
# Correct option: During starvation, muscle proteins break down into glutamate and goes into the blood directly
# Quality: 2.6
# --- longest option is correct
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Alanine carries amine group into liver for regeneration of glucose
# cleaned_string:  Branched chain amino acids are used to synthesize alanine
# cleaned_string:  Alanine transforms into alphaketo acid during transamination
# --- verb tense doesn't align between answer other options
# --- GPT-3 believes the answer is incorrect:  Alanine transforms into alpha-keto acid during transamination   During starvation, muscle proteins break down into glutamate and goes into the blood directly
# Question: Match the following analogy of the silicon IT model to how information is stored in the human body 1. The RAM (transient copy of some of the information) 2. The hard drive (containing a stable copy of information) 3. The Printer (outcome allowing the computer to run)
#  1. RNA 2. DNA 3. Protein
# 1. Protein 2. RNA 3. DNA
# 1. DNA 2. Protein 3. RNA
# 1. Replication 2. Transcription 3. Translation
# Correct option: 1. RNA 2. DNA 3. Protein
# Quality: 2.68
# repeating_nouns_synonyms:  ['rna', 'protein', 'dna']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  rna
# cleaned_string:  1 Protein 2 RNA 3 DNA
# cleaned_string:  1 DNA 2 Protein 3 RNA
# cleaned_string:  1 Replication 2 Transcription 3 Translation
# --- GPT-3 believes the answer is incorrect:  1. Protein 2. RNA 3. DNA   1. RNA 2. DNA 3. Protein
# Question: Fill in the blanks: As fat enters the digestive system, the ___________ contracts and squirts bile salts into the __________ . This emulsifies the fats, forming micelles, whilst digestive enzymes begin breaking down triglyceride. ________ lipase hydrolyses the fat into glycerol and fatty acids. After this, they are resynthesised into triglycerides.
#  gallbladder; large intestine; hepatic
# liver; large intestine; hepatic
# liver; small intestine; pancreatic
# gallbladder; small intestine; pancreatic
# Correct option: gallbladder; small intestine; pancreatic
# Quality: 2.72
# repeating_nouns_synonyms:  ['intestine', 'gallbladder']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  gallbladder
# --- fill in the blank
# --- absolute word in question stem
# cleaned_string:  gallbladder large intestine hepatic
# cleaned_string:  liver large intestine hepatic
# cleaned_string:  liver small intestine pancreatic
# --- GPT-3 believes the answer is incorrect:  liver; small intestine; pancreatic   gallbladder; small intestine; pancreatic
# Question: What is the main function of brown adipose tissue?
#  Energy Storage due to the multiple large lipid droplets in the adipocyte cell
# Uncoupling of protons due to Thermogenin protein, producing heat
# Insulation and organ cushioning due to low thermal conductivity
# To generate heat through the conversion of ATP into kinetic energy
# Correct option: Uncoupling of protons due to Thermogenin protein, producing heat
# Quality: 2.97
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['heat']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  heat
# cleaned_string:  Energy Storage due to the multiple large lipid droplets in the adipocyte cell
# cleaned_string:  Insulation and organ cushioning due to low thermal conductivity
# cleaned_string:  To generate heat through the conversion of ATP into kinetic energy
# opt_entity:  Preparation
# lemma_nouns_opt:  ['preparation']
# ans_entity:  Extension/ Elongation
# lemma_nouns_ans:  ['extension/', 'elongation']
# Question: Nucleotide triphosphates (dNTPs) are added to the growing DNA strand during the _______________ phase.
#  Denaturation/ Separation
# Annealing
# Extension/ Elongation
# Preparation
# Correct option: Extension/ Elongation
# Quality: 2.78
# --- distractor not similar enough
# Extension/ Elongation 		 Preparation 		 Score: 0.0882
# Question: Nucleotide triphosphates (dNTPs) are added to the growing DNA strand during the _______________ phase.
#  Denaturation/ Separation
# Annealing
# Extension/ Elongation
# Preparation
# Correct option: Extension/ Elongation
# Quality: 2.78
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- fill in the blank
# --- Question stem does not contain a question
# cleaned_string:  Denaturation Separation
# cleaned_string:  Annealing
# cleaned_string:  Preparation
# --- verb tense doesn't align between answer other options
# Question: Which of the following is false regarding transamination reactions?
#  The aspartate aminotransferase transfers an &alpha;-amino group from aspartate to &alpha;-ketoglutarate to form glutamate and oxaloacetate.
# Transamination reactions are reversible, allowing for catabolism and synthesis of amino acids.
# Transamination helpsto divert the excess amino acids towards energy generation.
# The &alpha;-amino group is directly transferred from the amino acid to&alpha;-ketoglutarate using only aspartate or alanine aminotransferases.
# Correct option: The &alpha;-amino group is directly transferred from the amino acid to&alpha;-ketoglutarate using only aspartate or alanine aminotransferases.
# Quality: 2.52
# repeating_nouns_synonyms:  ['group', 'alpha', 'aminotransferase']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  group
# --- absolute word in question stem
# cleaned_string:  The aspartate aminotransferase transfers an alphaamino group from aspartate to alphaketoglutarate to form glutamate and oxaloacetate
# cleaned_string:  Transamination reactions are reversible allowing for catabolism and synthesis of amino acids
# cleaned_string:  Transamination helpsto divert the excess amino acids towards energy generation
# --- verb tense doesn't align between answer other options
# opt_entity:  None of the above
# lemma_nouns_opt:  ['none']
# ans_entity:  The overall ATP utilization is greater in gluconeogenesis than in glycolysis
# lemma_nouns_ans:  ['atp', 'utilization', 'gluconeogenesis', 'glycolysis']
# Question: Which of the statements is true about gluconeogenesis?
#  Gluconeogenesis is a non-ubiquitous/universal process
# Gluconeogenesis is a catabolic pathway
# The overall ATP utilization is greater in gluconeogenesis than in glycolysis
# None of the above
# Correct option: The overall ATP utilization is greater in gluconeogenesis than in glycolysis
# Quality: 2.54
# --- none of the above
# Question: Which of the statements is true about gluconeogenesis?
#  Gluconeogenesis is a non-ubiquitous/universal process
# Gluconeogenesis is a catabolic pathway
# The overall ATP utilization is greater in gluconeogenesis than in glycolysis
# None of the above
# Correct option: The overall ATP utilization is greater in gluconeogenesis than in glycolysis
# Quality: 2.54
# --- none of the above
# --- longest option is correct
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- The answer entity is not found in any other options:  ORG
# --- absolute word in question stem
# cleaned_string:  Gluconeogenesis is a nonubiquitousuniversal process
# cleaned_string:  Gluconeogenesis is a catabolic pathway
# cleaned_string:  None of the above
# --- GPT-3 believes the answer is incorrect:  None of the above   The overall ATP utilization is greater in gluconeogenesis than in glycolysis
# Question: Which force contributes the most to stabilizing the DNA double-helix?
#  a) Hydrophobic bases are found in the interior of the helix where each base- pair is stabilized by the same number of hydrogen bonds.
# b) Hydrophilic sugar-phosphate groups are found on the exterior of the helix where they can interact with water.
# c) Non-covalent N-glycosidic bonds can form between nitrogenous bases in opposite strands in the helix.
# d) Covalent base-stacking interactions can occur between adjacent bases within the same strand in the helix.
# Correct option: b) Hydrophilic sugar-phosphate groups are found on the exterior of the helix where they can interact with water.
# Quality: 2.77
# repeating_nouns_synonyms:  ['helix']
# repeating_nouns_synonyms:  ['helix']
# repeating_nouns_synonyms:  ['helix']
# cleaned_string:  a Hydrophobic bases are found in the interior of the helix where each base pair is stabilized by the same number of hydrogen bonds
# cleaned_string:  c Noncovalent Nglycosidic bonds can form between nitrogenous bases in opposite strands in the helix
# cleaned_string:  d Covalent basestacking interactions can occur between adjacent bases within the same strand in the helix
# --- verb tense doesn't align between answer other options
# --- GPT-3 believes the answer is incorrect:  c) Non-covalent N-glycosidic bonds can form between nitrogenous bases in opposite strands in the helix.   b) Hydrophilic sugar-phosphate groups are found on the exterior of the helix where they can interact with water.
# Question: Why do Type I diabetics experience weight loss?
#  Type I diabetics have high glucose levels. This causes the pancreatic Beta cells to work harder, which causes uncoupling and leads to weight loss.
# A symptom of Type I diabetes is polyuria. The frequent urination is due to low glucose osmotic concentration in the blood. This causes a decrease in weight.
# Type I diabetics have low insulin levels. The low insulin causes activation of lipolysis and proteolysis, which causes weight loss.
# Type I diabetics exhibit glucosuria. The kidneys absorb all the glucose in the blood and excrete it in the urine. This causes starvation and weight loss.
# Correct option: Type I diabetics have low insulin levels. The low insulin causes activation of lipolysis and proteolysis, which causes weight loss.
# Quality: 2.76
# repeating_nouns_synonyms:  ['loss', 'level', 'type']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  loss
# --- absolute word in question stem
# cleaned_string:  Type I diabetics have high glucose levels This causes the pancreatic Beta cells to work harder which causes uncoupling and leads to weight loss
# cleaned_string:   symptom of Type I diabetes is polyuria The frequent urination is due to low glucose osmotic concentration in the blood This causes a decrease in weight
# cleaned_string:  Type I diabetics exhibit glucosuria The kidneys absorb all the glucose in the blood and excrete it in the urine This causes starvation and weight loss
# Question: Which of the following is incorrect about the structure and function of ATP Synthase?
#  ATP Synthase can use a proton gradient to generate ATP
# The F 0 channel is composed of 12 cylindrical proteins
# As protons enter the ATPase pump, the gamma subunit stops rotating to allow them to pass through
# When protons enter ATPase, the beta subunits of F 1 to change in conformation to accept ADP and Pi and react them to release ATP
# Correct option: As protons enter the ATPase pump, the gamma subunit stops rotating to allow them to pass through
# Quality: 2.96
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['proton', 'subunit']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  proton
# --- absolute word in question stem
# cleaned_string:  ATP Synthase can use a proton gradient to generate ATP
# cleaned_string:  The  0 channel is composed of 12 cylindrical proteins
# cleaned_string:  When protons enter ATPase the beta subunits of  1 to change in conformation to accept ADP and Pi and react them to release ATP
# --- verb tense doesn't align between answer other options
# --- GPT-3 believes the answer is incorrect:  When protons enter ATPase, the beta subunits of F 1 to change in conformation to accept ADP and Pi and react them to release ATP   As protons enter the ATPase pump, the gamma subunit stops rotating to allow them to pass through
# --- Question stem is unclear
# Question: Which of the one of the following statements about glucose is false ?
#  More energy is stored in triglycerides compared to glucose.
# Acetyl-CoA can be converted back into pyruvate to be re-stored as glucose.
# The brain uses glucose as its primary fuel source under normal conditions.
# Glycogen is stored in the liver, which is then broken down into pyruvate during glycolysis.
# Correct option: Acetyl-CoA can be converted back into pyruvate to be re-stored as glucose.
# Quality: 3.0
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- The answer entity is not found in any other options:  ORG
# cleaned_string:  More energy is stored in triglycerides compared to glucose
# cleaned_string:  The brain uses glucose as its primary fuel source under normal conditions
# cleaned_string:  Glycogen is stored in the liver which is then broken down into pyruvate during glycolysis
# --- verb tense doesn't align between answer other options
# --- Question stem is unclear
# Question: Increased thirsty is one of the symptoms of Type I diabetes. Which option can explain the increased thirsty feeling of Type 1 Diabetes patients?
#  High glucose levels will lead to increased sweating, so Type I diabetes patients will feel thirsty easily.
# Insulin secretion has linear relationship with salivary secretion, less insulin secretion less saliva secretion.
# Excess glucose is excreted into patient's urine, it pulls fluids from patient's tissues. Which causing dehydrated.
# Salivary gland will be blocked, due to the high glucose levels of Type I diabetes patients.
# Correct option: Excess glucose is excreted into patient's urine, it pulls fluids from patient's tissues. Which causing dehydrated.
# Quality: 3.04
# repeating_nouns_synonyms:  ['patient']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  patient
# --- This might be a K-type question
# --- verb tense doesn't align between answer other options
# Question: An individual decides to take up a high carbohydrate diet . Which lipoprotein would MOST LIKELY increase in the blood?
#  chylomicrons
# VLDL (very low-density lipoprotein)
# LDL (low-density lipoprotein)
# HDL (high-density lipoprotein)
# Correct option: VLDL (very low-density lipoprotein)
# Quality: 3.1
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['lipoprotein']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  lipoprotein
# cleaned_string:  chylomicrons
# cleaned_string:  LDL lowdensity lipoprotein
# cleaned_string:  HDL highdensity lipoprotein
# Question: Coupling Rules Oxidative phosphorylation is the cumulative effort of fuel oxidation, electron transport and the manufacture of ATP. As such, oxidative phosphorylation is regulated by the heavy dependence of each of these processes on the other. Of the following statements regarding oxidative phosphorylation, which are true and which are false? I. Electrons move slowly down the electron transport chain (from NADH to oxygen) when there is a smaller proton gradient. II. Carriers such as ADP and NAD are present in large quantities, such that there is always a carrier available to pick up a phosphate or hydrogen molecule (respectively). III. When ATP is not hydrolysed to regenerate and release ADP, the proton (H+) gradient will remain high. IV. Without the proton (H+) gradient, ATP synthesis would cease.
#  III and IV are true I and II are false
# II and III are true I and IV are false
# I and III are true II and IV are false
# I and IV are true II and III are false
# Correct option: III and IV are true I and II are false
# Quality: 3.21
# --- CTTR above 4.5, text is too complex and extraneous:  5.207883182646716
# repeating_nouns_synonyms:  ['ii', 'iii']
# repeating_nouns_synonyms:  ['iv', 'ii', 'iii']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  iv
# cleaned_string:  II and III are true I and IV are false
# cleaned_string:  I and III are true II and IV are false
# cleaned_string:  I and IV are true II and III are false
# --- GPT-3 believes the answer is incorrect:  I and IV are true II and III are false   III and IV are true I and II are false
# Question: Which of the following is correct in describing the role of NAD+ in ATP synthesis?
#  The pumping of protons powered by NAD+ allows the uncoupling protein to dissipate the proton gradient, hence resulting in ATP synthesis.
# NAD+ breaks down fats and carbohydrates in the body, and that then provides the electrons for the electron transport chain, hence resulting in ATP synthesis.
# NAD+ is reduced to NADH via the breakdown of fats and carbohydrates in the body, and that then provides the electrons for the electron transport chain, hence resulting in ATP synthesis.
# NAD+ binds to the uncoupling protein to inhibit ATP synthesis
# Correct option: NAD+ is reduced to NADH via the breakdown of fats and carbohydrates in the body, and that then provides the electrons for the electron transport chain, hence resulting in ATP synthesis.
# Quality: 3.0
# repeating_nouns_synonyms:  ['atp', 'synthesis']
# repeating_nouns_synonyms:  ['transport', 'chain', 'synthesis', 'electron', 'atp', 'fat', 'body']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  transport
# --- absolute word in question stem
# cleaned_string:  The pumping of protons powered by NAD allows the uncoupling protein to dissipate the proton gradient hence resulting in ATP synthesis
# cleaned_string:  NAD breaks down fats and carbohydrates in the body and that then provides the electrons for the electron transport chain hence resulting in ATP synthesis
# cleaned_string:  NAD binds to the uncoupling protein to inhibit ATP synthesis
# --- verb tense doesn't align between answer other options
# Question: Which of these statements about lipolysis is false?
#  At2-3 days of starvation the triglycerides within fat are hydrolysed in white adipose tissue.
# The hydrolysis of fat is broken down into a glycerol and three fatty acids.
# Products of lipolysis aresecreted into the bloodstream and used as an energy source within the body.
# After 24 hours of starvation lipids are broken down into glucose and transported to the brain
# Correct option: After 24 hours of starvation lipids are broken down into glucose and transported to the brain
# Quality: 3.06
# repeating_nouns_synonyms:  ['starvation']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  starvation
# --- The answer entity is not found in any other options:  TIME
# cleaned_string:  At23 days of starvation the triglycerides within fat are hydrolysed in white adipose tissue
# cleaned_string:  The hydrolysis of fat is broken down into a glycerol and three fatty acids
# cleaned_string:  Products of lipolysis aresecreted into the bloodstream and used as an energy source within the body
# Question: Glucagon and insulin are hormones which help regulate blood glucose levels in early starvation. What kind of relationship do glucagon and insulin have DURING early starvation?
#  Linear relationship, when glucagon increases, insulin increases.
# Linear relationship, when glucagon decreases, insulin decreases.
# Inverse relationship, when glucagon decreases, insulin increases.
# Inverse relationship, when glucagon increases, insulin decreases.
# ...
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  meal
# --- absolute word in question stem
# cleaned_string:  The theory does not apply because metabolic performance DOES increase with smaller meals just like giving fire more fuel
# cleaned_string:  The theory does not apply because metabolic performance DOES increase with larger meals ie metabolism is regulated by fuel availability
# cleaned_string:  I dont know
# --- GPT-3 believes the answer is incorrect:  The theory does not apply because metabolic performance DOES increase with smaller meals( just like giving fire more fuel)   The theory does not apply because metabolic performance DOES NOT increase with smaller meals i.e. metabolism is not regulated by fuel availability( unlike fire).
# Question: Which is TRUE about the formation of a peptide bond during elongation?
#  The reaction is catalysed by the mRNA found in the large ribosomal subunit
# The fMet from the A site is transferred onto the amino acid at the P site
# The amine group at the A site launches a nucleophilic attack and breaks the ester linkage between the amino acid and the tRNA at the P site
# The effect of the forming of a peptide bond, is that the amino acid is transferred from the tRNA in the A site to the amino acid on the P site
# Correct option: The amine group at the A site launches a nucleophilic attack and breaks the ester linkage between the amino acid and the tRNA at the P site
# Quality: 3.65
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['p', 'a', 'site']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  p
# cleaned_string:  The reaction is catalysed by the mRNA found in the large ribosomal subunit
# cleaned_string:  The fMet from the  site is transferred onto the amino acid at the P site
# cleaned_string:  The effect of the forming of a peptide bond is that the amino acid is transferred from the tRNA in the  site to the amino acid on the P site
# --- verb tense doesn't align between answer other options
# --- GPT-3 believes the answer is incorrect:  The fMet from the A site is transferred onto the amino acid at the P site   The amine group at the A site launches a nucleophilic attack and breaks the ester linkage between the amino acid and the tRNA at the P site
# Question: Which of the following statements regarding ubiquinone is correct ?
#  Ubiquinone is a water-soluble electron carrier that transports electrons from Complex I to Complex III.
# Ubiquinone is a water-soluble electron carrier that transports electrons from Complex I to Complex II.
# Ubiquinone is a lipid-soluble electron carrier that transports electrons from Complex I to Complex III.
# Ubiquinone is a lipid-soluble electron carrier that transports electrons from Complex I to Complex II.
# Correct option: Ubiquinone is a lipid-soluble electron carrier that transports electrons from Complex I to Complex III.
# Quality: 3.56
# --- none of the above
# repeating_nouns_synonyms:  ['carrier', 'transport', 'electron', 'complex', 'iii']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  iii
# --- absolute word in question stem
# cleaned_string:  Ubiquinone is a watersoluble electron carrier that transports electrons from Complex I to Complex III
# cleaned_string:  Ubiquinone is a watersoluble electron carrier that transports electrons from Complex I to Complex II
# cleaned_string:  Ubiquinone is a lipidsoluble electron carrier that transports electrons from Complex I to Complex II
# --- GPT-3 believes the answer is incorrect:  Ubiquinone is a water-soluble electron carrier that transports electrons from Complex I to Complex II.   Ubiquinone is a lipid-soluble electron carrier that transports electrons from Complex I to Complex III.
# Question: Derek is a healthy 20 year old male and in his spare time, he likes to play tennis. Being the curious biochemistry student that he is, Derek makes a few predictions about what occurs in his body at the cellular level when he plays tennis. Which of the following predictions and the reasoning behind them is INCORRECT? These are the following scenarios which Derek imagines (some highly implausible, but nonetheless are part of Derek&rsquo;s imagination)
#  If Derek is playing tennis for over 2 hours at a moderate to high intensity level, then the increase in work will cause ATP consumption to INCREASE, rate of proton pumping to INCREASE, and oxygen consumption will INCREASE.
# If Derek decides that the weather is too hot and decides to lie down on the tennis court instead of exercising, then the decrease in work will cause ATP consumption to DECREASE, rate of proton pumping to DECREASE, and oxygen consumption will DECREASE.
# If Derek had a gigantic feast of KFC in the middle of his tennis session and there is now a readily available amount of fuel for his body to metabolise, then the rate of ATP synthesis will INCREASE, rate of proton pumping will INCREASE and oxygen consumption will also INCREASE.
# If Derek suddenly experiences a stroke or heart attack whilst playing tennis and his cells become hypoxic (ie lack of oxygen), the rate of ATP synthesis STOPS, electron transfer to oxygen SLOWS and hence rate of proton pumping STOPS and oxygen consumption STOPS.
# Correct option: If Derek had a gigantic feast of KFC in the middle of his tennis session and there is now a readily available amount of fuel for his body to metabolise, then the rate of ATP synthesis will INCREASE, rate of proton pumping will INCREASE and oxygen consumption will also INCREASE.
# Quality: 3.6
# repeating_nouns_synonyms:  ['proton', 'increase', 'oxygen', 'consumption', 'atp', 'rate', 'tennis']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  increase
# --- This might be a K-type question
# --- verb tense doesn't align between answer other options
# --- GPT-3 believes the answer is incorrect:  If Derek decides that the weather is too hot and decides to lie down on the tennis court instead of exercising, then the decrease in work will cause ATP consumption to DECREASE, rate of proton pumping to DECREASE, and oxygen consumption will DECREASE.   If Derek had a gigantic feast of KFC in the middle of his tennis session and there is now a readily available amount of fuel for his body to metabolise, then the rate of ATP synthesis will INCREASE, rate of proton pumping will INCREASE and oxygen consumption will also INCREASE.
# Question: You want the initial rate of the reaction to be about 0.75 absorbance units per minute. What is this rate of change expressed in moles per minute in the well? Extinction Coefficient: 15 mM -1 cm -1 ,200uL solution with cuvette length of 1cm.
#  50 nmol min -1
# 10 nmol min -1
# 5 nmol min- 1
# 15nmol min -1
# Correct option: 10 nmol min -1
# Quality: 3.58
# repeating_nouns_synonyms:  ['min']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  min
# cleaned_string:  50 nmol min 1
# cleaned_string:  5 nmol min 1
# cleaned_string:  15nmol min 1
# Question: With exams looming, your room in is a state of disarray. You don't know if you can comfort yourself with the confidence of being able to pass your BCHM exam but maybe the messiness of your room could help. Clothes, folders, sheets of paper, bags, food and cups are strewn everywhere and you can't find a single thing. This is reminiscent of amino acids because there are so many different individual molecules- just like there are so many individual things around your room. Which of the following in the analogy does NOT reflect amino acid metabolism?
#  You realise the protocol you need for your lab is missing. But did you print it? No matter how many folders and A4 sheets you have around the house, if you didn't print it, it's not going to be there, just like if you don't eat a particular essential amino acid, it's not going to magically appear...
# When you finally get around to cleaning up your room, everything has its own place and method of disposing- cups will be washed as do clothes but notes will be filed away. This is like amino acids where each amino acid has a separate route of metabolism and disposal.
# Cleaning up will probably require you to leave your room to go to the bin or the kitchen to put back the uneaten food or wash the cups. Unfortunately, you cannot hole up in there forever :( just like amino acid disposal will span the over different organs
# Just like folding your clothes into piles and storing cups and food in a nicer, cleaner fashion, the body can shuffle amino acids around and restructure them into molecules except it is a process that doesn't need a cofactor or ATP.
# Correct option: Just like folding your clothes into piles and storing cups and food in a nicer, cleaner fashion, the body can shuffle amino acids around and restructure them into molecules except it is a process that doesn't need a cofactor or ATP.
# Quality: 3.55
# --- CTTR above 4.5, text is too complex and extraneous:  4.928571428571429
# repeating_nouns_synonyms:  ['acid']
# repeating_nouns_synonyms:  ['clothes', 'acid', 'cup']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  clothes
# --- absolute word in question stem
# --- This might be a K-type question
# --- verb tense doesn't align between answer other options
# Question: Which list is the correct order for the following processes of the lagging strand in E.coli replication? i. DNA ligase works to seal the gaps in the sugar phosphate backbone ii. DNA pol I uses 5' to 3' exonuclease activity to remove the primer iii. The lagging strand is synthesized in short Okazaki fragments iv. DNA pol I uses 5' to 3' polymerase activity to fill the gaps
#  i, ii, iv, iii
# iii, iv, ii, i
# iii, ii, iv, i
# ii, i, iv, iii
# Correct option: iii, ii, iv, i
# Quality: 3.5
# repeating_nouns_synonyms:  ['iv', 'ii', 'iii']
# repeating_nouns_synonyms:  ['iv', 'ii', 'iii']
# repeating_nouns_synonyms:  ['iv', 'ii', 'iii']
# --- This might be a K-type question
# --- GPT-3 believes the answer is incorrect:  ii, i, iv, iii   iii, ii, iv, i
# Question: Glucose oxidation is the process of formation of 2 pyruvic acids, 2 net ATPs and 2 NADHs from glucose. During strenuous exercise, oxygen may become unavailable or insufficient leading to overproduction of lactate. With that in mind, what is the main reason why lactate is formed ?
#  Pyruvate cannot be converted into acetyl-CoA , as the process requires an oxygen molecule.
# Replenishment of NAD+. Production of lactate replenishes NAD+ stocks by consuming NADH molecules (one NADH per lactate), thus allowing glycolysis to proceed.
# Prevent further strain on the muscles. Lactate is only produced when exercising, as it is an important physiological mechanism of defense against further strain on the muscles. It causes pain in the area because of its acidic profile, thus conserving muscle integrity by preventing further exercise.olecule.
# Prevent cell lysis. Lactate is produced as a way to prevent the cell from lysing due to the buildup of pyruvic acid. Unlike lactate, pyruvic acid cannot be transported to the liver to be converted to glucose, so its build-up can be lethal to the cell.
# Correct option: Replenishment of NAD+. Production of lactate replenishes NAD+ stocks by consuming NADH molecules (one NADH per lactate), thus allowing glycolysis to proceed.
# Quality: 3.76
# repeating_nouns_synonyms:  ['molecule']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  molecule
# --- The answer entity is not found in any other options:  PERSON
# --- absolute word in question stem
# --- This might be a K-type question
# --- verb tense doesn't align between answer other options
# Question: In which of the following scenarios would a person exhibit the greatest activity of ATP-Citrate Lyase?
#  After eating a light breakfast
# While running for the train
# While watching a lecture and taking notes
# After eating a huge dinner and going to bed
# Correct option: After eating a huge dinner and going to bed
# Quality: 3.52
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  After eating a light breakfast
# cleaned_string:  While running for the train
# cleaned_string:  While watching a lecture and taking notes
# --- GPT-3 believes the answer is incorrect:  While running for the train   After eating a huge dinner and going to bed
# Question: Fat distribution after digestion. Rhonda is visiting the doctor after suffering abdominal pain and inflammation and deposits of fatty material in the skin. A blood sample is taken and centrifuged to reveal a creamy layer in the plasma. What could be the cause of Rhonda's condition?
#  Abetalipoproteinemia, the inability of the body to make certain lipoproteins.
# Cystic fibrosis causing a thick, mostly impenetrable mucus to line epithelial cells in both the pancreas and in the intestine.
# Gall stones in her gallbladder preventing bile salts from being secreted in the intestine.
# Chylomicronemia syndrome, a mutation of the gene coding for lipoprotein lipase resulting in an inability to produce the protein.
# Correct option: Chylomicronemia syndrome, a mutation of the gene coding for lipoprotein lipase resulting in an inability to produce the protein.
# Quality: 3.54
# repeating_nouns_synonyms:  ['inability']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  inability
# --- The answer entity is not found in any other options:  PERSON
# --- absolute word in question stem
# cleaned_string:  Abetalipoproteinemia the inability of the body to make certain lipoproteins
# cleaned_string:  Cystic fibrosis causing a thick mostly impenetrable mucus to line epithelial cells in both the pancreas and in the intestine
# cleaned_string:  Gall stones in her gallbladder preventing bile salts from being secreted in the intestine
# ambiguous_unclear_information :  4
# implausible_distractors :  9
# none_of_the_above :  3
# longest_answer_correct :  2
# gratuitous_information_in_stem :  5
# true_or_false :  11
# avoid_convergence_cues :  36
# avoid_logical_cues :  6
# all_of_the_above :  0
# fill_in_the_blank :  3
# absolute_terms :  19
# word_repeats_in_stem_and_correct_answer :  0
# unfocused_stem :  4
# complex_k_type :  9
# grammatical_cues_in_stem :  24
# lost_sequence :  0
# vague_terms :  0
# more_than_one_correct :  24
# negative_worded_stem :  14
# qid :  -201652207
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[337], line 111
#     109 #Print the number of "Falses", which correspond to IWF, found the table across each criteria
#     110 for c in columns:
# --> 111     print(c, ': ', (~peerwise_biochem_results[c]).values.sum())
#
# File ~\anaconda3\envs\aied23\lib\site-packages\pandas\core\generic.py:1522, in NDFrame.__invert__(self)
#    1518 if not self.size:
#    1519     # inv fails with 0 len
#    1520     return self
# -> 1522 new_data = self._mgr.apply(operator.invert)
#    1523 return self._constructor(new_data).__finalize__(self, method="__invert__")
#
# File ~\anaconda3\envs\aied23\lib\site-packages\pandas\core\internals\managers.py:350, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     348 try:
#     349     if callable(f):
# --> 350         applied = b.apply(f, **kwargs)
#     351     else:
#     352         applied = getattr(b, f)(**kwargs)
#
# File ~\anaconda3\envs\aied23\lib\site-packages\pandas\core\internals\blocks.py:351, in Block.apply(self, func, **kwargs)
#     345 @final
#     346 def apply(self, func, **kwargs) -> list[Block]:
#     347     """
#     348     apply the function to my values; return a block if we are not
#     349     one
#     350     """
# --> 351     result = func(self.values, **kwargs)
#     353     return self._split_op_result(result)
#
# TypeError: ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# ## OLI Chemistry Data - 50 Questions

# %%
# qs = pd.read_csv('oli_chemistry_questions.csv')
# qs = qs.fillna('')

# oli_chemistry_student_questions = []
# for index, row in qs.iterrows():
#     question = MultipleChoiceQuestion(
#         stem=row['question'],
#         options=[row['altA'], row['altB'], row['altC'], row['altD']],
#         correct_option= row['altA']
#     )
#     oli_chemistry_student_questions.append(question)

# rows = []
# i = 0
# for q in oli_chemistry_student_questions:
#     r = [ambiguous_unclear_information(q),
#         implausible_distractors(q),
#         none_of_the_above(q),
#         longest_answer_correct(q),
#         gratuitous_information_in_stem(q),
#         true_or_false(q),
#         avoid_convergence_cues(q),
#         avoid_logical_cues(q),
#         all_of_the_above(q),
#         fill_in_the_blank(q),
#         absolute_terms(q),
#         word_repeats_in_stem_and_correct_answer(q),
#         unfocused_stem(q),
#         complex_k_type(q),
#         grammatical_cues_in_stem(q),
#         lost_sequence(q),
#         vague_terms(q),
#         more_than_one_correct(q),
#         negative_worded_stem(q)]
#     rows.append(r)
#     i += 1
#     print(i)

# columns = [
#     'ambiguous_unclear_information',
#     'implausible_distractors',
#     'none_of_the_above',
#     'longest_answer_correct',
#     'gratuitous_information_in_stem',
#     'true_or_false',
#     'avoid_convergence_cues',
#     'avoid_logical_cues',
#     'all_of_the_above',
#     'fill_in_the_blank',
#     'absolute_terms',
#     'word_repeats_in_stem_and_correct_answer',
#     'unfocused_stem',
#     'complex_k_type',
#     'grammatical_cues_in_stem',
#     'lost_sequence',
#     'vague_terms',
#     'more_than_one_correct',
#     'negative_worded_stem'
# ]

# oli_chemistry_results = pd.DataFrame(rows, columns=columns)
# oli_chemistry_results.to_csv("chem_results_auto_iwf.csv")

# #Print the number of "Falses", which correspond to IWF, found the table across each criteria
# for c in columns:
#     print(c, ': ', (~oli_chemistry_results[c]).values.sum())
# Out:
# opt_entity:  All of the above
# lemma_nouns_opt:  []
# ans_entity:  Proton
# lemma_nouns_ans:  ['proton']
# Question: Which particle weighs the least in an atom?
#  Proton
# Electron
# Neutron
# All of the above
# Correct option: Proton
# Quality: None
# --- distractor not similar enough
# Proton 		 All of the above 		 Score: 0.1279
# Question: Which particle weighs the least in an atom?
#  Proton
# Electron
# Neutron
# All of the above
# Correct option: Proton
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Electron
# cleaned_string:  Neutron
# cleaned_string:  All of the above
# --- GPT-3 believes the answer is incorrect:  Electron   Proton
# 1
# opt_entity:  Rutherford
# lemma_nouns_opt:  ['rutherford']
# ans_entity:  Millikan
# lemma_nouns_ans:  ['millikan']
# *** low score, but they are the same entity ORG  &  ORG
# Question: Which scientist discovered the fundamental electric charge, the charge of an electron?
#  Millikan
# Rutherford
# Dalton
# Thomson
# Correct option: Millikan
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Rutherford
# cleaned_string:  Dalton
# cleaned_string:  Thomson
# 2
# Question: The atomic number determines how many ____ are in the nucleus.
#  Protons
# Electrons
# Neutrons
# Atoms
# Correct option: Protons
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- fill in the blank
# cleaned_string:  Electrons
# cleaned_string:  Neutrons
# cleaned_string:  Atoms
# 3
# --- Question stem is unclear
# Question: what does the atomic number represent of the element?
#  proton
# neutron
# electron
# none
# Correct option: proton
# Quality: None
# --- none of the above
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- absolute word in question stem
# cleaned_string:  neutron
# cleaned_string:  electron
# cleaned_string:  none
# 4
# Question: According to the concept of atomic theory which of the following is true?
#  Dalton emphasized that atoms are neither created nor destroyed during a chemical change but are actually rearranged.
# Dalton emphasized that atoms are created during a chemical change.
# Dalton emphasized that atoms are destroyed during a chemical change.
# Dalton emphasized that atoms are large in size.
# Correct option: Dalton emphasized that atoms are neither created nor destroyed during a chemical change but are actually rearranged.
# Quality: None
# --- longest option is correct
# repeating_nouns_synonyms:  ['atom', 'change', 'dalton']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  change
# --- absolute word in question stem
# cleaned_string:  Dalton emphasized that atoms are created during a chemical change
# cleaned_string:  Dalton emphasized that atoms are destroyed during a chemical change
# cleaned_string:  Dalton emphasized that atoms are large in size
# 5
# Question: what is the center of an atom called?
#  Nucleus
# proton
# neutron
# electron
# Correct option: Nucleus
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  proton
# cleaned_string:  neutron
# cleaned_string:  electron
# 6
# Question: What is the difference between a proton and a neutron?
#  A proton has a negative charge and a neutron has a positive charge.
# A proton is bigger than a neutron.
# A proton can change charges while a neutron can not.
# A proton has a positive charge, a neutron has no charge.
# Correct option: A proton has a negative charge and a neutron has a positive charge.
# Quality: None
# repeating_nouns_synonyms:  ['proton']
# repeating_nouns_synonyms:  ['charge', 'proton']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  charge
# cleaned_string:   proton is bigger than a neutron
# cleaned_string:   proton can change charges while a neutron can not
# cleaned_string:   proton has a positive charge a neutron has no charge
# --- verb tense doesn't align between answer other options
# --- GPT-3 believes the answer is incorrect:  A proton has a positive charge, a neutron has no charge.   A proton has a negative charge and a neutron has a positive charge.
# 7
# Question: what are the sub-particles of an atom?
#  b and c.
# neutron
# proton and electron
# atom
# Correct option: b and c.
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  neutron
# cleaned_string:  proton and electron
# cleaned_string:  atom
# --- GPT-3 believes the answer is incorrect:  proton and electron   b and c.
# 8
# Question: Where can the electrons be located?
#  the nucleus
# outside the nucleus
# outside the atom
# on the periodic table
# Correct option: the nucleus
# Quality: None
# repeating_nouns_synonyms:  ['nucleus']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  nucleus
# cleaned_string:  outside the nucleus
# cleaned_string:  outside the atom
# cleaned_string:  on the periodic table
# --- GPT-3 believes the answer is incorrect:  outside the nucleus   the nucleus
# 9
# opt_entity:  None of the above
# lemma_nouns_opt:  ['none']
# ans_entity:  Protons and neutrons
# lemma_nouns_ans:  ['proton', 'neutron']
# Question: Which two particles make up most of the atoms mass?
#  Protons and neutrons
# Protons and Electrons
# Neutrons and Electrons
# None of the above
# Correct option: Protons and neutrons
# Quality: None
# --- none of the above
# Question: Which two particles make up most of the atoms mass?
#  Protons and neutrons
# Protons and Electrons
# Neutrons and Electrons
# None of the above
# Correct option: Protons and neutrons
# Quality: None
# --- none of the above
# repeating_nouns_synonyms:  ['proton']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  proton
# cleaned_string:  Protons and Electrons
# cleaned_string:  Neutrons and Electrons
# cleaned_string:  None of the above
# 10
# Question: How many electrons does Carbon have?
#  13
# 0
# 6
# 7
# Correct option: 13
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  0
# cleaned_string:  6
# cleaned_string:  7
# --- Options are numeric and not sorted
# --- GPT-3 believes the answer is incorrect:  7   13
# 11
# opt_entity:  Aristotle
# lemma_nouns_opt:  ['aristotle']
# ans_entity:  Chadwick
# lemma_nouns_ans:  ['chadwick']
# Question: Who found the existence of the neutron?
#  Chadwick
# Rutherford
# Aristotle
# Dalton
# Correct option: Chadwick
# Quality: None
# --- distractor not similar enough
# Chadwick 		 Aristotle 		 Score: 0.1396
# Question: Who found the existence of the neutron?
#  Chadwick
# Rutherford
# Aristotle
# Dalton
# Correct option: Chadwick
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Rutherford
# cleaned_string:  Aristotle
# cleaned_string:  Dalton
# 12
# opt_entity:  Not this one
# lemma_nouns_opt:  []
# ans_entity:  Positively charged particle consisting of two protons and two neutrons
# lemma_nouns_ans:  ['particle', 'proton', 'neutron']
# *** low score, but they are the same entity CARDINAL  &  CARDINAL
# Question: What are alpha particles?
#  Positively charged particle consisting of two protons and two neutrons
# Negatively charged particle consisting of two protons and two neutrons
# Not this one
# You missed it!! Hint: It's A, like they said
# Correct option: Positively charged particle consisting of two protons and two neutrons
# Quality: None
# repeating_nouns_synonyms:  ['proton', 'neutron', 'particle']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  proton
# cleaned_string:  Negatively charged particle consisting of two protons and two neutrons
# cleaned_string:  Not this one
# cleaned_string:  You missed it Hint Its  like they said
# 13
# Question: An atom has an atomic number of 6 and a mass number of 13. Identify the element.
#  Carbon
# Nitrogen
# Aluminium
# Chlorine
# Correct option: Carbon
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Nitrogen
# cleaned_string:  Aluminium
# cleaned_string:  Chlorine
# 14
# Question: Who coined the term, "electron"?
#  JJ Thompson
# Robert A Millikan
# George Stoney
# Rutherford
# Correct option: JJ Thompson
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Robert  Millikan
# cleaned_string:  George Stoney
# cleaned_string:  Rutherford
# 15
# Question: How can you determine the mass?
#  the sum of protons and neutrons
# sum of protons
# sum of neurtrons
# sum of electrons
# Correct option: the sum of protons and neutrons
# Quality: None
# --- longest option is correct
# repeating_nouns_synonyms:  ['proton']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  proton
# cleaned_string:  sum of protons
# cleaned_string:  sum of neurtrons
# cleaned_string:  sum of electrons
# 16
# Question: which of these subatomic particles are neutral or uncharged in the atom?
#  neutrons
# electrons
# protons
# atom
# Correct option: neutrons
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  electrons
# cleaned_string:  protons
# cleaned_string:  atom
# 17
# Question: For Carbon to be neutral how many electrons must it have?
#  2
# 3
# 4
# 6
# Correct option: 2
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  3
# cleaned_string:  4
# cleaned_string:  6
# --- GPT-3 believes the answer is incorrect:  4   2
# 18
# opt_entity:  Millikan
# lemma_nouns_opt:  ['millikan']
# ans_entity:  Thomson
# lemma_nouns_ans:  ['thomson']
# *** low score, but they are the same entity ORG  &  ORG
# Question: Who was responsible for finding the charge of an electron?
#  Thomson
# Chadwick
# Rutherford
# Millikan
# Correct option: Thomson
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Chadwick
# cleaned_string:  Rutherford
# cleaned_string:  Millikan
# 19
# opt_entity:  Millikan
# lemma_nouns_opt:  ['millikan']
# ans_entity:  Rutherford
# lemma_nouns_ans:  ['rutherford']
# *** low score, but they are the same entity ORG  &  ORG
# Question: Who used the "gold foil experiment" to show how atoms have a small, dense, positively charged nucleus?
#  Rutherford
# Millikan
# Chadwick
# Thomson
# Correct option: Rutherford
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Millikan
# cleaned_string:  Chadwick
# cleaned_string:  Thomson
# 20
# Question: Electron are negatively charged?
#  Yes
# No
# Neutral
# None
# Correct option: Yes
# Quality: None
# --- none of the above
# --- There is a true/false or yes/no answer choice
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  No
# cleaned_string:  Neutral
# cleaned_string:  None
# 21
# Question: All matter is composed of small indivisible particles called atoms
#  TRUE
# FALSE
# None
# None
# Correct option: TRUE
# Quality: None
# --- none of the above
# --- There is a true/false or yes/no answer choice
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- Question stem does not contain a question
# cleaned_string:  FALSE
# cleaned_string:  None
# cleaned_string:  None
# 22
# Question: An unknown atom was found. Test have concluded that it weighed about 55 amu, and 29 neutrons were discovered. What element is the atom?
#  Iron
# Copper
# Cobalt
# Manganese
# Correct option: Iron
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Copper
# cleaned_string:  Cobalt
# cleaned_string:  Manganese
# --- GPT-3 believes the answer is incorrect:  Copper   Iron
# 23
# Question: What did the results of Robert A. Millikan's Oil Drop experiment show?
#  The charge of an electron
# The charge of a proton
# The charge of a neutron
# The mass of a proton
# Correct option: The charge of an electron
# Quality: None
# repeating_nouns_synonyms:  ['charge']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  charge
# cleaned_string:  The charge of a proton
# cleaned_string:  The charge of a neutron
# cleaned_string:  The mass of a proton
# 24
# Question: An atom has an atomic number of 19. What is the name of the element
#  Potassium
# Sodium
# Calcium
# Carbon
# Correct option: Potassium
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Sodium
# cleaned_string:  Calcium
# cleaned_string:  Carbon
# --- GPT-3 believes the answer is incorrect:  Calcium   Potassium
# 25
# opt_entity:  Leucippus
# lemma_nouns_opt:  ['leucippus']
# ans_entity:  JJ. Thompson
# lemma_nouns_ans:  ['jj', 'thompson']
# Question: Which physicist discovered the Cathode Ray Experiment?
#  JJ. Thompson
# Robert A. Milikan
# Aristotle
# Leucippus
# Correct option: JJ. Thompson
# Quality: None
# --- distractor not similar enough
# JJ. Thompson 		 Leucippus 		 Score: 0.1083
# Question: Which physicist discovered the Cathode Ray Experiment?
#  JJ. Thompson
# Robert A. Milikan
# Aristotle
# Leucippus
# Correct option: JJ. Thompson
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- The answer entity is not found in any other options:  ORG
# cleaned_string:  Robert  Milikan
# cleaned_string:  Aristotle
# cleaned_string:  Leucippus
# 26
# Question: which subatomic particle is positively charged?
#  proton
# neutron
# electron
# atom
# Correct option: proton
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  neutron
# cleaned_string:  electron
# cleaned_string:  atom
# 27
# opt_entity:  neither
# lemma_nouns_opt:  []
# ans_entity:  number of protons
# lemma_nouns_ans:  ['number', 'proton']
# Question: how do you get number of neutrons?
#  number of protons
# total number of neutrons and protons
# mass number minus atomic number
# neither
# Correct option: number of protons
# Quality: None
# --- none of the above
# Question: how do you get number of neutrons?
#  number of protons
# total number of neutrons and protons
# mass number minus atomic number
# neither
# Correct option: number of protons
# Quality: None
# --- none of the above
# repeating_nouns_synonyms:  ['number', 'proton']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  number
# cleaned_string:  total number of neutrons and protons
# cleaned_string:  mass number minus atomic number
# cleaned_string:  neither
# --- GPT-3 believes the answer is incorrect:  mass number minus atomic number   number of protons
# 28
# opt_entity:  Milikan
# lemma_nouns_opt:  ['milikan']
# ans_entity:  Rutherford
# lemma_nouns_ans:  ['rutherford']
# Question: Which scientist discovered that protons are centered in the nucleus of an atom?
#  Rutherford
# Thomson
# Chadwick
# Milikan
# Correct option: Rutherford
# Quality: None
# --- distractor not similar enough
# Rutherford 		 Milikan 		 Score: 0.1097
# Question: Which scientist discovered that protons are centered in the nucleus of an atom?
#  Rutherford
# Thomson
# Chadwick
# Milikan
# Correct option: Rutherford
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Thomson
# cleaned_string:  Chadwick
# cleaned_string:  Milikan
# --- GPT-3 believes the answer is incorrect:  Chadwick   Rutherford
# 29
# --- Question stem is unclear
# Question: what kind of charge does an atoms nucleus have?
#  An atom consists of a positively charged nucleus
# An atom consists of a negatively charged nucleus
# An atom consists of a neutrally charged nucleus
# An atom consists of no charge
# Correct option: An atom consists of a positively charged nucleus
# Quality: None
# repeating_nouns_synonyms:  ['atom', 'nucleus']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  nucleus
# --- absolute word in question stem
# cleaned_string:  An atom consists of a negatively charged nucleus
# cleaned_string:  An atom consists of a neutrally charged nucleus
# cleaned_string:  An atom consists of no charge
# 30
# opt_entity:  AMU
# lemma_nouns_opt:  ['amu']
# ans_entity:  atomic number
# lemma_nouns_ans:  ['number']
# Question: what is the number of protons in the nucleus called?
#  atomic number
# AMU
# Mass
# atomic mass
# Correct option: atomic number
# Quality: None
# --- distractor not similar enough
# atomic number 		 AMU 		 Score: 0.1035
# Question: what is the number of protons in the nucleus called?
#  atomic number
# AMU
# Mass
# atomic mass
# Correct option: atomic number
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  AMU
# cleaned_string:  Mass
# cleaned_string:  atomic mass
# 31
# Question: what is contained in the nucleus and what is outside of the nucleus
#  neutrons only inside and protons outside
# Protons and electrons inside and neutrons outside
# protons  and neutrons  inside and electrons outside
# electrons only inside and neutrons and protons outside
# Correct option: neutrons only inside and protons outside
# Quality: None
# repeating_nouns_synonyms:  ['neutron', 'proton']
# repeating_nouns_synonyms:  ['neutron', 'proton']
# repeating_nouns_synonyms:  ['neutron', 'proton']
# --- absolute word in question stem
# cleaned_string:  Protons and electrons inside and neutrons outside
# cleaned_string:  protons  and neutrons  inside and electrons outside
# cleaned_string:  electrons only inside and neutrons and protons outside
# --- GPT-3 believes the answer is incorrect:  protons  and neutrons  inside and electrons outside   neutrons only inside and protons outside
# 32
# Question: What is the electrical charge of a atom?
#  It is neutral
# It is negative
# It is positive
# The atomic number equals the charge
# Correct option: It is neutral
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  It is negative
# cleaned_string:  It is positive
# cleaned_string:  The atomic number equals the charge
# --- verb tense doesn't align between answer other options
# 33
# Question: What is the main difference between definite and multiple proportions?
#  One will contain the same elements while other reacts to form.
# The both form with any elements.
# The elements will come to react to proportion.
# Mass proportions will be the same.
# Correct option: One will contain the same elements while other reacts to form.
# Quality: None
# --- longest option is correct
# repeating_nouns_synonyms:  ['element', 'form']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  element
# cleaned_string:  The both form with any elements
# cleaned_string:  The elements will come to react to proportion
# cleaned_string:  Mass proportions will be the same
# --- GPT-3 believes the answer is incorrect:  Mass proportions will be the same.   One will contain the same elements while other reacts to form.
# 34
# Question: where does most of the mass of an atom come from?
#  protons and neutrons
# protons
# neutrons
# electrons
# Correct option: protons and neutrons
# Quality: None
# --- longest option is correct
# repeating_nouns_synonyms:  ['proton']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  proton
# cleaned_string:  protons
# cleaned_string:  neutrons
# cleaned_string:  electrons
# 35
# Question: Which particle weighs less than others with a charge of 1- and a mass of 0.00055 amu?
#  Electrons
# Protons
# Neutons
# Atom
# Correct option: Electrons
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Protons
# cleaned_string:  Neutons
# cleaned_string:  Atom
# 36
# Question: Who made the discovery of electrons?
#  Ernest Rutherford
# Robert A. Millikan
# J. J. Thomson
# John Dalton
# Correct option: Ernest Rutherford
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Robert  Millikan
# cleaned_string:  J J Thomson
# cleaned_string:  John Dalton
# --- GPT-3 believes the answer is incorrect:  J. J. Thomson   Ernest Rutherford
# 37
# Question: An atom has 8 protons and an atomic mass of 18. What's the total number of neutrons in the atom?
#  8
# 2
# 16
# 24
# Correct option: 8
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  2
# cleaned_string:  16
# cleaned_string:  24
# --- Options are numeric and not sorted
# --- GPT-3 believes the answer is incorrect:  24   8
# 38
# Question: Which subatomic particle has no charge?
#  Neutron
# Electron
# Atom
# Proton
# Correct option: Neutron
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Electron
# cleaned_string:  Atom
# cleaned_string:  Proton
# 39
# opt_entity:  none of the above
# lemma_nouns_opt:  ['none']
# ans_entity:  -1
# lemma_nouns_ans:  ['-1']
# Question: What charge does a proton have?
#  -1
# 1
# 0
# none of the above
# Correct option: -1
# Quality: None
# --- none of the above
# Question: What charge does a proton have?
#  -1
# 1
# 0
# none of the above
# Correct option: -1
# Quality: None
# --- none of the above
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- absolute word in question stem
# cleaned_string:  1
# cleaned_string:  0
# cleaned_string:  none of the above
# --- GPT-3 believes the answer is incorrect:  1   -1
# 40
# opt_entity:  None of the above
# lemma_nouns_opt:  ['none']
# ans_entity:  1+
# lemma_nouns_ans:  []
# Question: What is the charge of a proton?
#  1+
# 0
# 1-
# None of the above
# Correct option: 1+
# Quality: None
# --- none of the above
# Question: What is the charge of a proton?
#  1+
# 0
# 1-
# None of the above
# Correct option: 1+
# Quality: None
# --- none of the above
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  0
# cleaned_string:  1
# cleaned_string:  None of the above
# 41
# Question: What subatomic particle has a charge of 1-?
#  Electron
# Proton
# Neutron
# Atom
# Correct option: Electron
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Proton
# cleaned_string:  Neutron
# cleaned_string:  Atom
# 42
# Question: who discovered that the nucleus has neutral particles called neutrons?
#  Chadwick
# Thomson
# Millikan
# Rutherford
# Correct option: Chadwick
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- The answer entity is not found in any other options:  PERSON
# cleaned_string:  Thomson
# cleaned_string:  Millikan
# cleaned_string:  Rutherford
# 43
# Question: Who discovered the electron?
#  J.J Thomson
# Ernest Rutherford
# Robert Milikan
# James Chadwick
# Correct option: J.J Thomson
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Ernest Rutherford
# cleaned_string:  Robert Milikan
# cleaned_string:  James Chadwick
# 44
# Question: What is the difference between isotopes and ions?
#  neutrons
# electrons
# both A and B
# protons
# Correct option: neutrons
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  electrons
# cleaned_string:  both  and
# cleaned_string:  protons
# --- GPT-3 believes the answer is incorrect:  both A and B   neutrons
# 45
# Question: What did the gold foil experiment demonstrate?
#  The atom is mostly empty space
# Neutrons
# Electrons
# Nucleus
# Correct option: The atom is mostly empty space
# Quality: None
# --- longest option is correct
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# cleaned_string:  Neutrons
# cleaned_string:  Electrons
# cleaned_string:  Nucleus
# 46
# Question: Which particle determines the atomic number on the periodic table?
#  proton
# neutron
# electrom
# none
# Correct option: proton
# Quality: None
# --- none of the above
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- absolute word in question stem
# cleaned_string:  neutron
# cleaned_string:  electrom
# cleaned_string:  none
# 47
# Question: What are protons?
#  positively charged particle
# sum the number of protons and neutrons
# subatomic particle
# He discovers the charge of electron.
# Correct option: positively charged particle
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  ['particle']
# --- we have a synonym of the answer being used in other answer choices, but not all of them:  particle
# cleaned_string:  sum the number of protons and neutrons
# cleaned_string:  subatomic particle
# cleaned_string:  He discovers the charge of electron
# --- verb tense doesn't align between answer other options
# 48
# opt_entity:  compounds
# lemma_nouns_opt:  ['compound']
# ans_entity:  Indivisible
# lemma_nouns_ans:  []
# Question: All matter is composed of small,______ particles, called atoms.
#  Indivisible
# Chemical
# compounds
# reactions
# Correct option: Indivisible
# Quality: None
# --- distractor not similar enough
# Indivisible 		 compounds 		 Score: 0.1662
# Question: All matter is composed of small,______ particles, called atoms.
#  Indivisible
# Chemical
# compounds
# reactions
# Correct option: Indivisible
# Quality: None
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# repeating_nouns_synonyms:  []
# --- fill in the blank
# --- Question stem does not contain a question
# cleaned_string:  Chemical
# cleaned_string:  compounds
# cleaned_string:  reactions
# 49
# Question: What is the number of protons in the nucleus is called?
#  the atomic number (Z)
# the atomic number is (A)
# the atomic number is (N)
# the atomic number is (C)
# Correct option: the atomic number (Z)
# Quality: None
# repeating_nouns_synonyms:  ['number']
# repeating_nouns_synonyms:  ['number']
# repeating_nouns_synonyms:  ['number']
# cleaned_string:  the atomic number is
# cleaned_string:  the atomic number is N
# cleaned_string:  the atomic number is
# 50
# ambiguous_unclear_information :  2
# implausible_distractors :  6
# none_of_the_above :  8
# longest_answer_correct :  5
# gratuitous_information_in_stem :  0
# true_or_false :  3
# avoid_convergence_cues :  12
# avoid_logical_cues :  2
# all_of_the_above :  0
# fill_in_the_blank :  2
# absolute_terms :  6
# word_repeats_in_stem_and_correct_answer :  0
# unfocused_stem :  2
# complex_k_type :  0
# grammatical_cues_in_stem :  3
# lost_sequence :  2
# vague_terms :  0
# more_than_one_correct :  16
# negative_worded_stem :  0

# %% [markdown]
# ## OLI CollabU - 50 Questions

# %%
# qs = pd.read_csv('oli_collabu_questions.csv')
# qs = qs.fillna('')

# oli_collabu_student_questions = []
# for index, row in qs.iterrows():
#     question = MultipleChoiceQuestion(
#         stem=row['question'],
#         options=[row['altA'], row['altB'], row['altC'], row['altD']],
#         correct_option= row['altA']
#     )
#     oli_collabu_student_questions.append(question)

# rows = []
# i = 0
# for q in oli_collabu_student_questions:
#     r = [ambiguous_unclear_information(q),
#         implausible_distractors(q),
#         none_of_the_above(q),
#         longest_answer_correct(q),
#         gratuitous_information_in_stem(q),
#         true_or_false(q),
#         avoid_convergence_cues(q),
#         avoid_logical_cues(q),
#         all_of_the_above(q),
#         fill_in_the_blank(q),
#         absolute_terms(q),
#         word_repeats_in_stem_and_correct_answer(q),
#         unfocused_stem(q),
#         complex_k_type(q),
#         grammatical_cues_in_stem(q),
#         lost_sequence(q),
#         vague_terms(q),
#         more_than_one_correct(q),
#         negative_worded_stem(q)]
#     rows.append(r)
#     i += 1
#     print(i)

# columns = [
#     'ambiguous_unclear_information',
#     'implausible_distractors',
#     'none_of_the_above',
#     'longest_answer_correct',
#     'gratuitous_information_in_stem',
#     'true_or_false',
#     'avoid_convergence_cues',
#     'avoid_logical_cues',
#     'all_of_the_above',
#     'fill_in_the_blank',
#     'absolute_terms',
#     'word_repeats_in_stem_and_correct_answer',
#     'unfocused_stem',
#     'complex_k_type',
#     'grammatical_cues_in_stem',
#     'lost_sequence',
#     'vague_terms',
#     'more_than_one_correct',
#     'negative_worded_stem'
# ]

# oli_collabu_results = pd.DataFrame(rows, columns=columns)
# oli_collabu_results.to_csv("collabu_results_auto_iwf.csv")
# #Print the number of "Falses", which correspond to IWF, found the table across each criteria
# for c in columns:
#     print(c, ': ', (~oli_collabu_results[c]).values.sum())

# %% [markdown]
# ## OLI Stats - 50 Questions

# %%
# qs = pd.read_csv('oli_stats_questions.csv')
# qs = qs.fillna('')

# oli_stats_student_questions = []
# for index, row in qs.iterrows():
#     question = MultipleChoiceQuestion(
#         stem=row['question'],
#         options=[row['altA'], row['altB'], row['altC'], row['altD']],
#         correct_option= row['altA']
#     )
#     oli_stats_student_questions.append(question)

# rows = []
# i = 0
# for q in oli_stats_student_questions:
#     r = [ambiguous_unclear_information(q),
#         implausible_distractors(q),
#         none_of_the_above(q),
#         longest_answer_correct(q),
#         gratuitous_information_in_stem(q),
#         true_or_false(q),
#         avoid_convergence_cues(q),
#         avoid_logical_cues(q),
#         all_of_the_above(q),
#         fill_in_the_blank(q),
#         absolute_terms(q),
#         word_repeats_in_stem_and_correct_answer(q),
#         unfocused_stem(q),
#         complex_k_type(q),
#         grammatical_cues_in_stem(q),
#         lost_sequence(q),
#         vague_terms(q),
#         more_than_one_correct(q),
#         negative_worded_stem(q)]
#     rows.append(r)
#     i += 1
#     print(i)

# columns = [
#     'ambiguous_unclear_information',
#     'implausible_distractors',
#     'none_of_the_above',
#     'longest_answer_correct',
#     'gratuitous_information_in_stem',
#     'true_or_false',
#     'avoid_convergence_cues',
#     'avoid_logical_cues',
#     'all_of_the_above',
#     'fill_in_the_blank',
#     'absolute_terms',
#     'word_repeats_in_stem_and_correct_answer',
#     'unfocused_stem',
#     'complex_k_type',
#     'grammatical_cues_in_stem',
#     'lost_sequence',
#     'vague_terms',
#     'more_than_one_correct',
#     'negative_worded_stem'
# ]

# oli_stats_results = pd.DataFrame(rows, columns=columns)
# oli_stats_results.to_csv("stats_results_auto_iwf.csv")
# #Print the number of "Falses", which correspond to IWF, found the table across each criteria
# for c in columns:
#     print(c, ': ', (~oli_stats_results[c]).values.sum())
